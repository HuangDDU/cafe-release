# %%
import cfe 

fadata = cfe.data.read_h5ad("bifurcating_fadata.h5ad")
fadata
# Out:
# [2025年07月11日 08时27分31秒] INFO
#                                           _____     _ _ ______    _       ______            _
#                                          / ____|   | | |  ____|  | |     |  ____|          | |
#                                         | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                         | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                         | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                          \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                                      | |
#                                                                                      |_|
# AnnData object with n_obs × n_vars = 100 × 250
# ...

# %%
# TODO: cxgxf打包后要能够一键执行
fadata.launch_cellxgene()
# Out:
# [2025年07月11日 08时27分36秒] INFO     🌐 Server start at: http://127.0.0.1:5005
# [2025年07月11日 08时27分47秒] INFO     🛑 Server top!!!
