# %%
import cafe
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3
# INFO      Version: 0.1.3

# %% [markdown]
# data

# %%
fadata = cafe.data.read_pancreas()
fadata

# %% [markdown]
# plot stream

# %%
figs = cafe.plot.plot_stream(
    fadata, 
    color="clusters",
    mode="cell",
    fig_size=(12, 6),
)

figs = cafe.plot.plot_stream(
    fadata, 
    color="clusters",
    mode="density",
    fig_size=(12, 6),
)
# Out:
# INFO     |- Preparing FateAnnData for stream plotting (model: ref)
# INFO     |- FateAnnData prepared successfully for stream plotting
# INFO     |- Plotting stream_sc with color: ['clusters']
# INFO     |- FateAnnData prepared successfully for stream plotting
# INFO     |- Plotting stream_sc with color: ['clusters']
