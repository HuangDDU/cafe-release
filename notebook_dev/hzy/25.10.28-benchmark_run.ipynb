# %%
import cfe

cfe.logger.setLevel("DEBUG")
cfe.settings.backend = "cfe_docker"
# Out:
# [10/27/2025 11:31:02] INFO
#                                   _____     _ _ ______    _       ______            _
#                                  / ____|   | | |  ____|  | |     |  ____|          | |
#                                 | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                 | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                 | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                  \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                              | |
#                                                                              |_|

# %%
fadata = cfe.data.read_pancrease()
cfe.plot.plot_trajectory(fadata)
# Out:
#                       DEBUG    Reading data from '/root/PyCode/scRNA/data/Pancreas/endocrinogenesis_day15.h5ad'...
# [10/27/2025 11:31:03] DEBUG    transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    add prior information 'start_cell': 'cell_1103'
# [10/27/2025 11:31:04] DEBUG    FateAnnData add_trajectory
#                       DEBUG    extract 'clusters' from prior infomation as parameter 'color'
#                       DEBUG    extract 'X_umap' from prior infomation as parameter 'basis'
#                       DEBUG    calculate new trajectory embedding for model_name:ref, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:31:07] DEBUG    add waypoints shape is (212, 3696) for 'ref', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    'ref' is not a valid random_time_string, don't need parse
# <Axes: title={'center': 'ref(clusters)'}, xlabel='X_umap1', ylabel='X_umap2'>

# %%
method2parameters = {
    "scvelo": {},
    "palantir": {},
    "stavia": {},
}

for method_name, parameters in method2parameters.items():
    parameters["repreprocess"] = False # use common preprocessing
    parameters["benchmark_resource"] = True # record resource usage
    method = cfe.method.FateMethod(method_name=method_name)
    method.infer_trajectory(fadata, parameters=parameters)
# Out:
#                       DEBUG    CFEDockerBackend __init__
#                       DEBUG    Docker image(huangzhaoyang/scvelo:0.0.1) loaded, entry point is 'None'
#                       DEBUG    Loaded function 'scvelo': <function scvelo at 0x7f71149e5bd0>
#                       INFO     method backend loaded: CFE Docker Backend: scvelo in docker image 'huangzhaoyang/scvelo:0.0.1'
#                       DEBUG    merged parameters: {'repreprocess': False}
#                       DEBUG    Temp wd: /tmp/tmp5hjkdros
# [10/27/2025 11:31:08] INFO     GPU access requested for the container.
# [10/27/2025 11:31:11] DEBUG    /usr/local/lib/python3.10/site-packages/scvelo/tools/velocity.py:326: DeprecationWarning: Automatic neighbor calculation is deprecated since scvelo==0.4.0 and will be
#                                removed in a future version of scVelo. Please compute neighbors first with Scanpy.
#                       DEBUG    moments(adata)
#                       DEBUG    /usr/local/lib/python3.10/site-packages/scvelo/preprocessing/moments.py:71: DeprecationWarning: `neighbors` is deprecated since scvelo==0.4.0 and will be removed in a
#                                future version of scVelo. Please compute neighbors with Scanpy.
#                       DEBUG    neighbors(
# [10/27/2025 11:31:37] DEBUG    /usr/local/lib/python3.10/site-packages/scvelo/tools/optimization.py:184: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will
#                                error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#                       DEBUG    gamma[i] = np.linalg.pinv(A.T.dot(A)).dot(A.T.dot(y[:, i]))
# [10/27/2025 11:31:38] DEBUG    Normalized count data: X, spliced, unspliced.
#                       DEBUG    computing neighbors
#                       DEBUG    finished (0:00:09) --> added
#                       DEBUG    'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
#                       DEBUG    computing moments based on connectivities
#                       DEBUG    finished (0:00:03) --> added
#                       DEBUG    'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#                       DEBUG    computing velocities
#                       DEBUG    finished (0:00:13) --> added
#                       DEBUG    'velocity', velocity vectors for each individual cell (adata.layers)
#                       DEBUG    computing velocity graph (using 1/16 cores)
#                       DEBUG    WARNING: Unable to create progress bar. Consider installing `tqdm` as `pip install tqdm` and `ipywidgets` as `pip install ipywidgets`,
#                       DEBUG    or disable the progress bar using `show_progress_bar=False`.
# [10/27/2025 11:31:58] DEBUG    finished (0:00:18) --> added
#                       DEBUG    'velocity_graph', sparse matrix with cosine correlations (adata.uns)
#                       DEBUG    scvelo finish!
# [10/27/2025 11:31:59] DEBUG    Docker Finish
#                       DEBUG    resource usage dict: {'memory': 4734.86, 'cpu': 0, 'time': 50.892553091049194}
#                       DEBUG    Add trajectory by wrapper type: velocity
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    filterd adata: AnnData object with n_obs × n_vars = 3696 × 27998
#                                    obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score', 'raw_index'
#                                    var: 'highly_variable_genes'
#                                    uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca', 'id', 'cfe', 'filename'
#                                    obsm: 'X_pca', 'X_umap'
#                                    layers: 'spliced', 'unspliced', 'expression', 'counts'
#                                    obsp: 'distances', 'connectivities'
#                       DEBUG    add raw velocity embedding to fadata
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# WARNING: The neighbor graph has an unexpected format (e.g. computed outside scvelo)
# or is corrupted (e.g. due to subsetting). Consider recomputing with `pp.neighbors`.
# computing terminal states
#     identified 2 regions of root cells and 1 region of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# running PAGA using priors: ['velocity_pseudotime']
#     finished (0:00:00) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)
# [10/27/2025 11:32:02] DEBUG    milestone_network:             from             to  length  directed
#                                1     Ngn3 low EP         Ductal       1      True
#                                17    Ngn3 low EP   Ngn3 high EP       1      True
#                                26   Ngn3 high EP  Pre-endocrine       1      True
#                                35  Pre-endocrine           Beta       1      True
#                                43  Pre-endocrine          Alpha       1      True
#                                51  Pre-endocrine          Delta       1      True
#                                59  Pre-endocrine        Epsilon       1      True
#                       DEBUG    FateAnnData add_trajectory
# [10/27/2025 11:32:03] INFO     method infer trajectory successfully: CFE Docker Backend: scvelo in docker image 'huangzhaoyang/scvelo:0.0.1'
#                       DEBUG    CFEDockerBackend __init__
#                       DEBUG    Docker image(huangzhaoyang/palantir:0.0.1) loaded, entry point is 'None'
#                       DEBUG    Loaded function 'palantir': <function palantir at 0x7f711510b1c0>
#                       INFO     method backend loaded: CFE Docker Backend: palantir in docker image 'huangzhaoyang/palantir:0.0.1'
#                       DEBUG    extract prior information automatically: {'start_cell', 'cluster'}
#                       DEBUG    merged parameters: {'repreprocess': False, 'start_cell': 'cell_1103', 'cluster': 'clusters'}
#                       DEBUG    Temp wd: /tmp/tmpvtbnetn5
#                       INFO     GPU access requested for the container.
# [10/27/2025 11:32:30] DEBUG    Sampling and flocking waypoints...
#                       DEBUG    Time for determining waypoints: 0.0037167946497599284 minutes
#                       DEBUG    Determining pseudotime...
#                       DEBUG    Shortest path distances using 30-nearest neighbor graph...
# [10/27/2025 11:32:37] DEBUG    Time for shortest paths: 0.11048330863316853 minutes
#                       DEBUG    Iteratively refining the pseudotime...
#                       DEBUG    Correlation at iteration 1: 1.0000
#                       DEBUG    Entropy and branch probabilities...
#                       DEBUG    Markov chain construction...
#                       DEBUG    Identification of terminal states...
#                       DEBUG    Computing fundamental matrix and absorption probabilities...
#                       DEBUG    Project results to all cells...
#                       DEBUG    palantir execute finish
#                       DEBUG    palantir finish!
# [10/27/2025 11:32:40] DEBUG    Docker Finish
#                       DEBUG    resource usage dict: {'memory': 4848.93, 'cpu': 0, 'time': 36.34511852264404}
#                       DEBUG    Add trajectory by wrapper type: linear
#                       DEBUG    FateAnnData add_trajectory
#                       INFO     method infer trajectory successfully: CFE Docker Backend: palantir in docker image 'huangzhaoyang/palantir:0.0.1'
#                       DEBUG    CFEDockerBackend __init__
#                       DEBUG    Docker image(huangzhaoyang/stavia:0.0.1) loaded, entry point is 'None'
#                       DEBUG    Loaded function 'stavia': <function stavia at 0x7f711bf90b80>
#                       INFO     method backend loaded: CFE Docker Backend: stavia in docker image 'huangzhaoyang/stavia:0.0.1'
#                       DEBUG    extract prior information automatically: {'start_cell', 'cluster'}
#                       DEBUG    merged parameters: {'repreprocess': False, 'start_cell': 'cell_1103', 'cluster': 'clusters'}
#                       DEBUG    Temp wd: /tmp/tmpdjryboc0
#                       INFO     GPU access requested for the container.
# [10/27/2025 11:32:45] DEBUG    /usr/local/lib/python3.10/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
#                       DEBUG    Dask dataframe query planning is disabled because dask-expr is not installed.
#                       DEBUG
#                       DEBUG    You can install it with `pip install dask[dataframe]` or `conda install dask`.
#                       DEBUG    This will raise in a future version.
#                       DEBUG
#                       DEBUG    warnings.warn(msg, FutureWarning)
# [10/27/2025 11:32:59] DEBUG    /usr/local/lib/python3.10/site-packages/scipy/sparse/_index.py:100: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is
#                                more efficient.
#                       DEBUG    self._set_intXint(row, col, x.flat[0])
#                       DEBUG    /usr/local/lib/python3.10/site-packages/phate/__init__.py
#                       DEBUG    2025-10-27 03:32:57.765755      Running VIA over input data of 3696 (samples) x 30 (features)
#                       DEBUG    2025-10-27 03:32:57.765771      Knngraph has 30 neighbors
#                       DEBUG    2025-10-27 03:32:58.835073      Finished global pruning of 30-knn graph used for clustering at level of 0.15. Kept 49.5 % of edges.
#                       DEBUG    2025-10-27 03:32:58.850810      Number of connected components used for clustergraph  is 1
#                       DEBUG    2025-10-27 03:32:58.984986      Commencing community detection
#                       DEBUG    2025-10-27 03:32:59.195134      Finished community detection. Found 53 clusters.
#                       DEBUG    2025-10-27 03:32:59.196199      Merging 31 very small clusters (<10)
#                       DEBUG    2025-10-27 03:32:59.197480      Finished detecting communities. Found 22 communities
#                       DEBUG    2025-10-27 03:32:59.197638      Making cluster graph. Global cluster graph pruning level: 0.15
#                       DEBUG    2025-10-27 03:32:59.203379      Graph has 1 connected components before pruning
#                       DEBUG    2025-10-27 03:32:59.204492      Graph has 2 connected components after pruning
#                       DEBUG    2025-10-27 03:32:59.206259      Graph has 1 connected components after reconnecting
#                       DEBUG    2025-10-27 03:32:59.206642      0.0% links trimmed from local pruning relative to start
#                       DEBUG    2025-10-27 03:32:59.206650      54.5% links trimmed from global pruning relative to start
#                       DEBUG    initial links 132 and final_links_n 132
#                       DEBUG    2025-10-27 03:32:59.209000      component number 0 out of  [0]
#                       DEBUG    2025-10-27 03:32:59.223178      group root method
#                       DEBUG    2025-10-27 03:32:59.223221      group root method
#                       DEBUG    2025-10-27 03:32:59.223241      group root method
#                       DEBUG    2025-10-27 03:32:59.223261      group root method
#                       DEBUG    2025-10-27 03:32:59.223280      group root method
#                       DEBUG    2025-10-27 03:32:59.223299      group root method
#                       DEBUG    2025-10-27 03:32:59.223318      group root method
#                       DEBUG    2025-10-27 03:32:59.223337      group root method
#                       DEBUG    2025-10-27 03:32:59.223356      group root method
#                       DEBUG    2025-10-27 03:32:59.223376      setting a dummy root
#                       DEBUG    cluster 0 has majority Beta
#                       DEBUG    cluster 1 has majority Pre-endocrine
#                       DEBUG    2025-10-27 03:32:59.227565      New root is 1 and majority Pre-endocrine
#                       DEBUG    cluster 2 has majority Ductal
#                       DEBUG    cluster 3 has majority Ductal
#                       DEBUG    cluster 4 has majority Alpha
#                       DEBUG    cluster 5 has majority Alpha
#                       DEBUG    cluster 6 has majority Ngn3 high EP
#                       DEBUG    cluster 7 has majority Ductal
#                       DEBUG    cluster 8 has majority Ductal
#                       DEBUG    cluster 9 has majority Pre-endocrine
#                       DEBUG    2025-10-27 03:32:59.228606      New root is 9 and majority Pre-endocrine
#                       DEBUG    cluster 10 has majority Ductal
#                       DEBUG    cluster 11 has majority Beta
#                       DEBUG    cluster 12 has majority Ngn3 high EP
#                       DEBUG    cluster 13 has majority Ngn3 low EP
#                       DEBUG    cluster 14 has majority Ngn3 high EP
#                       DEBUG    cluster 15 has majority Epsilon
#                       DEBUG    cluster 16 has majority Ngn3 high EP
#                       DEBUG    cluster 17 has majority Pre-endocrine
#                       DEBUG    2025-10-27 03:32:59.229667      New root is 17 and majority Pre-endocrine
#                       DEBUG    cluster 18 has majority Epsilon
#                       DEBUG    cluster 19 has majority Delta
#                       DEBUG    cluster 20 has majority Ductal
#                       DEBUG    cluster 21 has majority Ngn3 high EP
#                       DEBUG    2025-10-27 03:32:59.230096      Computing lazy-teleporting expected hitting times
#                       DEBUG    /usr/local/lib/python3.10/site-packages/pyVIA/core.py:176: UserWarning: WARNING: Implicitly set node IDs to the canonical node ordering due to missing IDs field in the
#                                raw CSR npz file. This warning message can be suppressed by setting implicit_ids to True in the read_npz function call, or by setting the --implicit_ids flag in the CLI
#                       DEBUG    g.set_node_ids(node_ids=None,
#                       DEBUG    2025-10-27 03:32:59.464783      Ended all multiprocesses, will retrieve and reshape
#                       DEBUG    2025-10-27 03:32:59.490863      start computing walks with rw2 method
# [10/27/2025 11:33:06] DEBUG    /usr/local/lib/python3.10/site-packages/pyVIA/core.py:176: UserWarning: WARNING: Implicitly set node IDs to the canonical node ordering due to missing IDs field in the
#                                raw CSR npz file. This warning message can be suppressed by setting implicit_ids to True in the read_npz function call, or by setting the --implicit_ids flag in the CLI
#                       DEBUG    g.set_node_ids(node_ids=None,
#                       DEBUG    0%|          | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300 [00:00<?, ?it/s]  0%|
#                                | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300
#                                [00:00<?, ?it/s]  0%|          | 0/1300 [00:00<?, ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:01<?,
#                                ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]
#                                0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:01<?, ?it/s]  0%|          | 0/1300 [00:02<?, ?it/s]  0%|
#                                | 0/1300 [00:02<?, ?it/s]  0%|          | 0/1300 [00:02<?, ?it/s]  0%|          | 0/1300 [00:02<?, ?it/s]  0%|          | 0/1300 [00:02<?, ?it/s]  0%|          | 0/1300
#                                [00:02<?, ?it/s]  0%|          | 0/1300 [00:02<?, ?it/s]  0%|          | 0/1300 [00:02<?, ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]  0%|          | 0/1300 [00:03<?,
#                                ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]
#                                0%|          | 0/1300 [00:03<?, ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]  0%|          | 0/1300 [00:03<?, ?it/s]  0%|
#                                | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300
#                                [00:04<?, ?it/s]  0%|          | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300 [00:04<?,
#                                ?it/s]  0%|          | 0/1300 [00:04<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]
#                                0%|          | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]  0%|
#                                | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:05<?, ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]  0%|          | 0/1300
#                                [00:06<?, ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]  0%|          | 0/1300 [00:06<?,
#                                ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]  0%|          | 0/1300 [00:06<?, ?it/s]
#                                0%|          | 0/1300 [00:07<?, ?it/s]  0%|          | 0/1300 [00:07<?, ?it/s]  0%|          | 0/1300 [00:07<?, ?it/s]100%|██████████| 1300/1300 [00:07<00:00,
#                                175.60it/s]100%|██████████| 1300/1300 [00:07<00:00, 175.59it/s]100%|██████████| 1300/1300 [00:07<00:00, 175.59it/s]
# [10/27/2025 11:33:07] DEBUG    memory for rw2 hittings times  2. Using rw2 based pt
#                       DEBUG    2025-10-27 03:33:06.989062      Identifying terminal clusters corresponding to unique lineages...
#                       DEBUG    2025-10-27 03:33:06.989072      Closeness:[0, 3, 4, 5, 7, 10, 11, 20, 21]
#                       DEBUG    2025-10-27 03:33:06.989077      Betweenness:[0, 1, 2, 3, 4, 5, 7, 9, 10, 11, 14, 19, 20, 21]
#                       DEBUG    2025-10-27 03:33:06.989080      Out Degree:[1, 2, 3, 5, 7, 8, 9, 10, 11, 19, 20, 21]
#                       DEBUG    2025-10-27 03:33:06.989191      Cluster 0 had 3 or more neighboring terminal states [1, 4, 11] and so we removed cluster 4
#                       DEBUG    2025-10-27 03:33:06.989228      Cluster 10 had 3 or more neighboring terminal states [3, 7, 20] and so we removed cluster 3
#                       DEBUG    2025-10-27 03:33:06.989237      We removed cluster 19 from the shortlist of terminal states
#                       DEBUG    2025-10-27 03:33:06.989326      Terminal clusters corresponding to unique lineages in this component are [0, 1, 2, 7, 9, 10, 11, 20, 21]
#                       DEBUG    2025-10-27 03:33:06.989336      Calculating lineage probability at memory 5
# [10/27/2025 11:33:12] DEBUG    /usr/local/lib/python3.10/site-packages/scipy/sparse/_index.py:100: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is
#                                more efficient.
#                       DEBUG    self._set_intXint(row, col, x.flat[0])
#                       DEBUG    0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|
#                                | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000
#                                [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:00<?, ?it/s]  0%|          | 0/1000 [00:01<?, ?it/s]  0%|          | 0/1000 [00:01<?,
#                                ?it/s]  0%|          | 0/1000 [00:01<?, ?it/s]  0%|          | 0/1000 [00:01<?, ?it/s]  0%|          | 0/1000 [00:01<?, ?it/s]  0%|          | 0/1000 [00:01<?, ?it/s]
#                                0%|          | 0/1000 [00:01<?, ?it/s]  0%|          | 0/1000 [00:01<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|
#                                | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000
#                                [00:02<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000 [00:02<?, ?it/s]  0%|          | 0/1000 [00:03<?,
#                                ?it/s]  0%|          | 0/1000 [00:03<?, ?it/s]  0%|          | 0/1000 [00:03<?, ?it/s]  0%|          | 0/1000 [00:03<?, ?it/s]  0%|          | 0/1000 [00:03<?, ?it/s]
#                                0%|          | 0/1000 [00:03<?, ?it/s]  0%|          | 0/1000 [00:03<?, ?it/s]  0%|          | 0/1000 [00:03<?, ?it/s]  0%|          | 0/1000 [00:03<?, ?it/s]  0%|
#                                | 0/1000 [00:03<?, ?it/s]  0%|          | 0/1000 [00:04<?, ?it/s]  0%|          | 0/1000 [00:04<?, ?it/s]  0%|          | 0/1000 [00:04<?, ?it/s]  0%|          | 0/1000
#                                [00:04<?, ?it/s]  0%|          | 0/1000 [00:04<?, ?it/s]  0%|          | 0/1000 [00:04<?, ?it/s]100%|██████████| 1000/1000 [00:04<00:00, 218.92it/s]100%|██████████|
#                                1000/1000 [00:04<00:00, 218.91it/s]100%|██████████| 1000/1000 [00:04<00:00, 218.90it/s]
#                       DEBUG    2025-10-27 03:33:11.604420      Cluster or terminal cell fate 0 is reached 681.0 times
#                       DEBUG    2025-10-27 03:33:11.626193      Cluster or terminal cell fate 1 is reached 525.0 times
#                       DEBUG    2025-10-27 03:33:11.649040      Cluster or terminal cell fate 2 is reached 251.0 times
#                       DEBUG    2025-10-27 03:33:11.670696      Cluster or terminal cell fate 7 is reached 319.0 times
#                       DEBUG    2025-10-27 03:33:11.691982      Cluster or terminal cell fate 9 is reached 221.0 times
#                       DEBUG    2025-10-27 03:33:11.712850      Cluster or terminal cell fate 10 is reached 319.0 times
#                       DEBUG    2025-10-27 03:33:11.730687      Cluster or terminal cell fate 11 is reached 680.0 times
#                       DEBUG    2025-10-27 03:33:11.751648      Cluster or terminal cell fate 20 is reached 319.0 times
#                       DEBUG    2025-10-27 03:33:11.773210      Cluster or terminal cell fate 21 is reached 46.0 times
#                       DEBUG    2025-10-27 03:33:11.778882      There are (9) terminal clusters corresponding to unique lineages {0: 'Beta', 1: 'Pre-endocrine', 2: 'Ductal', 7: 'Ductal', 9:
#                                'Pre-endocrine', 10: 'Ductal', 11: 'Beta', 20: 'Ductal', 21: 'Ngn3 high EP'}
#                       DEBUG    2025-10-27 03:33:11.778894      Begin projection of pseudotime and lineage likelihood
#                       DEBUG    2025-10-27 03:33:12.106831      Cluster graph layout based on forward biasing
#                       DEBUG    2025-10-27 03:33:12.108773      Starting make edgebundle viagraph...
#                       DEBUG    2025-10-27 03:33:12.108786      Make via clustergraph edgebundle
#                       DEBUG    2025-10-27 03:33:12.401056      Hammer dims: Nodes shape: (22, 2) Edges shape: (60, 3)
#                       DEBUG    2025-10-27 03:33:12.401690      Graph has 1 connected components before pruning
#                       DEBUG    2025-10-27 03:33:12.402976      Graph has 4 connected components after pruning
#                       DEBUG    2025-10-27 03:33:12.404666      Graph has 1 connected components after reconnecting
#                       DEBUG    2025-10-27 03:33:12.405034      31.7% links trimmed from local pruning relative to start
#                       DEBUG    2025-10-27 03:33:12.405045      48.3% links trimmed from global pruning relative to start
#                       DEBUG    initial links 60 and final_links_n 41
#                       DEBUG    2025-10-27 03:33:12.410793      Time elapsed 14.3 seconds
#                       DEBUG    stavia finish!
# [10/27/2025 11:33:13] DEBUG    Docker Finish
#                       DEBUG    resource usage dict: {'memory': 1030.08, 'cpu': 0, 'time': 32.644914627075195}
#                       DEBUG    Add trajectory by wrapper type: cluster
# [10/27/2025 11:33:14] DEBUG    FateAnnData add_trajectory
#                       INFO     method infer trajectory successfully: CFE Docker Backend: stavia in docker image 'huangzhaoyang/stavia:0.0.1'

# %%
model_name_list = fadata.get_all_model_name(parse=False)
color_list = ["clusters", "milestone"]

cfe.plot.plot_trajectory(fadata, model_name=model_name_list, color=color_list)
# Out:
#                       DEBUG    extract 'X_umap' from prior infomation as parameter 'basis'
#                       DEBUG    plot_trajectory
#                       DEBUG    'ref' is not a valid random_time_string, don't need parse
#                       DEBUG    plot_trajectory
# [10/27/2025 11:33:17] DEBUG    'ref' is not a valid random_time_string, don't need parse
# [10/27/2025 11:33:30] DEBUG    calculate new trajectory embedding for model_name:20251027_113107__scvelo-cfe_docker__ixvmqI5sTG, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:33:33] DEBUG    add waypoints shape is (210, 3696) for '20251027_113107__scvelo-cfe_docker__ixvmqI5sTG', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    plot_trajectory
# [10/27/2025 11:33:49] DEBUG    calculate new trajectory embedding for model_name:20251027_113203__palantir-cfe_docker__KZ09bCCcFo, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:33:55] DEBUG    add waypoints shape is (201, 3696) for '20251027_113203__palantir-cfe_docker__KZ09bCCcFo', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    plot_trajectory
# [10/27/2025 11:34:13] DEBUG    calculate new trajectory embedding for model_name:20251027_113240__stavia-cfe_docker__j0LT2KQ9PJ, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:34:17] DEBUG    add waypoints shape is (234, 3696) for '20251027_113240__stavia-cfe_docker__j0LT2KQ9PJ', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    plot_trajectory
#                       WARNING  The number of colors(22) is greater than the number of colors in the 'Set3' palette(12), and the 'husl' palette selection is used.
# <Axes: title={'center': 'stavia-cfe_docker(milestone)'}, xlabel='X_umap1', ylabel='X_umap2'>

# %%
fadata.write_trajectory_dict()
# Out:
# [10/27/2025 11:35:50] DEBUG    write trajectory 'ref' to '.cfe/trajectory_history/pancreas/ref.pkl'
#                       DEBUG    write trajectory '20251027_113107__scvelo-cfe_docker__ixvmqI5sTG' to '.cfe/trajectory_history/pancreas/20251027_113107__scvelo-cfe_docker__ixvmqI5sTG.pkl'
# [10/27/2025 11:35:51] DEBUG    write trajectory '20251027_113203__palantir-cfe_docker__KZ09bCCcFo' to '.cfe/trajectory_history/pancreas/20251027_113203__palantir-cfe_docker__KZ09bCCcFo.pkl'
#                       DEBUG    write trajectory '20251027_113240__stavia-cfe_docker__j0LT2KQ9PJ' to '.cfe/trajectory_history/pancreas/20251027_113240__stavia-cfe_docker__j0LT2KQ9PJ.pkl'
