# %% [markdown]
# # Benchmark

# %% [markdown]
# ## 1. Environment

# %%
import cafe
import scanpy as sc
import pandas as pd

# cafe.settings.backend = "python_function"
cafe.settings.backend = "conda"
# cafe.logger.setLevel("DEBUG")
cafe.logger.setLevel("INFO")
# Out:
# [09/05/2025 04:02:14] INFO
#                                   _____     _ _ ______    _       ______            _
#                                  / ____|   | | |  ____|  | |     |  ____|          | |
#                                 | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                 | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                 | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                  \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                              | |
#                                                                              |_|

# %% [markdown]
# ## 2. Data

# %%
# fadata = cafe.data.read_pancrease()
fadata = cafe.data.read_h5ad("../../tests/data/pancrease_scvelo_500_fadata.h5ad")
fadata
# Out:
# AnnData object with n_obs × n_vars = 500 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     uns: 'cfe'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'count', 'expression', 'spliced', 'unspliced'

# %%
start_cell = "cell_000"
pseudotime_key = "trajectory_pseudotime"
fadata.obs[pseudotime_key] = fadata.get_trajectory_pseudotime(start_cell=start_cell)

cluster_key = "clusters"
cafe.plot.plot_trajectory(fadata, color=[cluster_key, pseudotime_key])
# Out:
# <Axes: title={'center': 'trajectory_pseudotime'}, xlabel='UMAP1', ylabel='UMAP2'>

# %% [markdown]
# ## 3. Method

# %%
# # common preprocessing
# import scvelo as scv

# scv.pp.filter_and_normalize(fadata, min_shared_counts=20, n_top_genes=2000)
# scv.pp.moments(fadata, n_pcs=20, n_neighbors=10)
# fadata

# %%
cluster_key = "clusters"
cluster_key_list = ["milestone", cluster_key]

method2parameters = {
    "comp1": {
        "basis": "X_umap",
    },
    "cytotrace2":{
        # TODO: parameters need adjust
        # TODO: cluster_key need to be extract from prior information
        "cluster_key": cluster_key,
        "cytotrace2_kwargs": {
            # "disable_parallelization": True, # 关闭并行
            "max_cores": 8, # 使用并行并指定核数, 当细胞数较少时，建议减少核数否则会阻塞在分数平滑处
        }
    },
    "palantir": {
        "palantir_results_kwargs": {
            "early_cell": "cell_000",
        },
    },
}

for method_name, parameters in method2parameters.items():
    parameters["repreprocess"] = True
    parameters["benchmark_resource"] = True  # record resource usage
    method = cafe.method.FateMethod(method_name=method_name)
    method.infer_trajectory(fadata, parameters=parameters)
    cafe.plot.plot_trajectory(fadata, basis="umap", color=cluster_key_list)
# Out:
# [09/05/2025 04:02:17] INFO     method_backend: CondaBackend: function_name-cf_comp1, load_backend-cfe
# [09/05/2025 04:02:18] INFO     cmd: conda run -n cfe --no-capture-output /usr/bin/time -v python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_comp1 --adata_path=/tmp/tmpk1sj8zcg/adata.h5ad --prior_information=/tmp/tmpk1sj8zcg/prior_information.json
#                                --parameters=/tmp/tmpk1sj8zcg/parameters.json --output_filename=/tmp/tmpk1sj8zcg/output.pkl
# [09/05/2025 04:02:25] INFO     [stdout]cf_comp1 finish!
# [09/05/2025 04:02:32] INFO     method_backend: CondaBackend: function_name-cf_cytotrace2, load_backend-cytotrace2
#                       INFO     cmd: conda run -n cytotrace2 --no-capture-output /usr/bin/time -v python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_cytotrace2 --adata_path=/tmp/tmpmxnt52jb/adata.h5ad --prior_information=/tmp/tmpmxnt52jb/prior_information.json
#                                --parameters=/tmp/tmpmxnt52jb/parameters.json --output_filename=/tmp/tmpmxnt52jb/output.pkl
# [09/05/2025 04:02:40] INFO     [stdout]write expression matrix((27998, 500)) to  /tmp/tmpbbsy2dxg/cytotrace2_expression.csv
# [09/05/2025 04:02:43] INFO     [stdout]write annotation to /tmp/tmpbbsy2dxg/cytotrace2_annotations.csv
#                       INFO     [stdout]cytotrace2: Input parameters
#                       INFO     [stdout]    Input file: /tmp/tmpbbsy2dxg/cytotrace2_expression.csv
#                       INFO     [stdout]    Species: mouse
#                       INFO     [stdout]    Parallelization enabled: True
#                       INFO     [stdout]    Batch size: 20000
#                       INFO     [stdout]    Smoothing batch size: 1000
#                       INFO     [stdout]    Seed: 14
#                       INFO     [stdout]    Output directory: cytotrace2_results
#                       INFO     [stdout]    Plotting enabled: False
#                       INFO     [stdout]    Verbose mode enabled: True
#                       INFO     [stdout]    User-provided limit for number of cores to use: 8
#                       INFO     [stdout]cytotrace2: Loading dataset
# [09/05/2025 04:02:44] INFO     [stdout]cytotrace2: Dataset characteristics
#                       INFO     [stdout]    Number of input genes:  27998
#                       INFO     [stdout]    Number of input cells:  500
#                       INFO     [stdout]cytotrace2: The passed batch_size is greater than the number of cells in the subsample.
#                       INFO     [stdout]    Now setting batch_size to 500.
#                       INFO     [stdout]cytotrace2: Preprocessing
#                       INFO     [stdout]cytotrace2: The number of cells in your dataset is less than the specified smoothing batch size.
#                       INFO     [stdout]
#                       INFO     [stdout]    Model prediction will not be parallelized.
#                       INFO     [stdout]cytotrace2: Running 1 prediction batch(es) sequentially using 1 cores per batch.
# [09/05/2025 04:02:45] INFO     [stdout]cytotrace2: Initiated processing batch 1/1 with 500 cells
# [09/05/2025 04:02:58] INFO     [stdout]    14247 input genes are present in the model features.
# [09/05/2025 04:02:59] INFO     [stdout]cytotrace2: Performing initial model prediction
# [09/05/2025 04:04:10] INFO     [stdout]cytotrace2: Performing smoothing by diffusion
#                       INFO     [stdout]The passed subsample size is greater than the number of cells in the subsample.
#                       INFO     [stdout]    Now setting subsample size to 500.
# [09/05/2025 04:04:11] INFO     [stdout]cytotrace2: Performing smoothing by adaptive KNN
# [09/05/2025 04:04:17] INFO     [stdout]cytotrace2: Plotting disabled
#                       INFO     [stdout]cytotrace2: Finished.
#                       INFO     [stdout]cf_cytotrace2 finish!
# [09/05/2025 04:04:24] INFO     method_backend: CondaBackend: function_name-cf_palantir, load_backend-cfe
#                       INFO     cmd: conda run -n cfe --no-capture-output /usr/bin/time -v python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_palantir --adata_path=/tmp/tmpvu711iqw/adata.h5ad --prior_information=/tmp/tmpvu711iqw/prior_information.json
#                                --parameters=/tmp/tmpvu711iqw/parameters.json --output_filename=/tmp/tmpvu711iqw/output.pkl
# [09/05/2025 04:04:42] INFO     [stdout]repreprocess finish
# [09/05/2025 04:05:15] INFO     [stdout]Sampling and flocking waypoints...
#                       INFO     [stdout]Time for determining waypoints: 0.001675411065419515 minutes
#                       INFO     [stdout]Determining pseudotime...
#                       INFO     [stdout]Shortest path distances using 30-nearest neighbor graph...
# [09/05/2025 04:05:53] INFO     [stdout]Time for shortest paths: 0.631297504901886 minutes
#                       INFO     [stdout]Iteratively refining the pseudotime...
# [09/05/2025 04:05:54] INFO     [stdout]Correlation at iteration 1: 1.0000
#                       INFO     [stdout]Entropy and branch probabilities...
#                       INFO     [stdout]Markov chain construction...
#                       INFO     [stdout]Identification of terminal states...
# [09/05/2025 04:05:55] INFO     [stdout]Computing fundamental matrix and absorption probabilities...
# [09/05/2025 04:05:57] INFO     [stdout]Project results to all cells...
#                       INFO     [stdout]palantir execute finish
#                       INFO     [stdout]cf_palantir finish!

# %% [markdown]
# Show model name

# %%
parsed_model_name_list = fadata.get_all_model_name() # 解析后的模型名称
model_name_list = fadata.get_all_model_name(parse=False)
parsed_model_name_list, model_name_list
# Out:
# [09/05/2025 04:06:28] WARNING  'ref' is not a valid random_time_string, don't need parse
# (['ref', 'comp1-conda', 'cytotrace2-conda', 'palantir-conda'],
#  ['ref',
#   '20250905_160217__comp1-conda__fKZeYaKbTZ',
#   '20250905_160232__cytotrace2-conda__gRlSz3gROJ',
#   '20250905_160424__palantir-conda__6cKPwZTMIl'])

# %% [markdown]
# ## 4. Metric

# %%
# available metrics:
# cafe.metric.metrics

# metrics are chosen to be calculate
implemented = [
    # "edge_flip",
    "him",
    # "F1_branches",
    # "F1_milestones"
    # "correlation",
    # "rf_mse",
    # "rf_rsq",
    # "rf_nmse",
    # "lm_mse",
    # "lm_rsq",
    # "lm_nmse",
    # feature importance need to be fixed
    # "featureimp_cor", 
    # "featureimp_wcor",
    # "featureimp_ks",
    # "featureimp_wilcox",
    
]
# =========================================================================================================

# metric calculation
# extract all model names
models = fadata.trajectory_history_dict.keys()
fadata.update_uns_cfe() # update fadata.uns["cfe"]

# ensure waypoint wrapper for every model
for m in set(models) | {"ref"}:
    fadata.model_name = m
    if not fadata.is_wrapped_with_waypoints:
        fadata.add_waypoints()
        
# metric calculation and collect results
records = {}
for model in models:
    record = fadata.get_resource_usage(model) # extract resource usage
    if not (("angle" in model) or ("ref" in model)):
        # skip ref itself, skip ref angle (node loop may result in error)
        print(f"Calculating metrics for model: {model}")
        # metric calculation
        metric = cafe.metric.calculate_metrics(
            fadata,
            now_model=model,
            ref_model="ref",
            simplify=False, 
            metrics=implemented
        )
        # NOTE: add new psudotime correlation metric
        psudotime_corr = cafe.metric.calculate_pseudotime_correlation(
            fadata=fadata,
            # start_cell=start_cell,
            ref_start_milestone="Ductal",
            pred_start_milestone="milestone_begin",
            ref_model="ref",
            pred_model=model,
        )
        metric["psudotime_corr"] = psudotime_corr
        record.update(metric)
    records[model] = record
    

# metric dataframe
df = pd.DataFrame(records).T
styled_df = cafe.plot.style_benchmark(df)
df.to_csv("tmp/benchmark.csv")
styled_df
# Out:
# Calculating metrics for model: 20250905_160217__comp1-conda__fKZeYaKbTZ
# Calculating metrics for model: 20250905_160232__cytotrace2-conda__gRlSz3gROJ
# Calculating metrics for model: 20250905_160424__palantir-conda__6cKPwZTMIl
# <style type="text/css">
# #T_fcf5b_row0_col0, #T_fcf5b_row0_col1, #T_fcf5b_row0_col2, #T_fcf5b_row0_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_fcf5b_row0_col3, #T_fcf5b_row1_col3, #T_fcf5b_row2_col0, #T_fcf5b_row2_col1, #T_fcf5b_row2_col3, #T_fcf5b_row2_col4, #T_fcf5b_row3_col2, #T_fcf5b_row3_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_fcf5b_row1_col0, #T_fcf5b_row1_col1, #T_fcf5b_row2_col2, #T_fcf5b_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_fcf5b_row1_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_fcf5b_row1_col4 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_fcf5b_row3_col0 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_fcf5b_row3_col1 {
#   background-color: #b5df74;
#   color: #000000;
# }
# </style>
# <table id="T_fcf5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcf5b_level0_col0" class="col_heading level0 col0" >time</th>
#       <th id="T_fcf5b_level0_col1" class="col_heading level0 col1" >memory</th>
#       <th id="T_fcf5b_level0_col2" class="col_heading level0 col2" >cpu</th>
#       <th id="T_fcf5b_level0_col3" class="col_heading level0 col3" >him</th>
#       <th id="T_fcf5b_level0_col4" class="col_heading level0 col4" >psudotime_corr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcf5b_level0_row0" class="row_heading level0 row0" >ref</th>
#       <td id="T_fcf5b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_fcf5b_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_fcf5b_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_fcf5b_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_fcf5b_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fcf5b_level0_row1" class="row_heading level0 row1" >20250905_160217__comp1-conda__fKZeYaKbTZ</th>
#       <td id="T_fcf5b_row1_col0" class="data row1 col0" >6.2000</td>
#       <td id="T_fcf5b_row1_col1" class="data row1 col1" >664068.0000</td>
#       <td id="T_fcf5b_row1_col2" class="data row1 col2" >1.1400</td>
#       <td id="T_fcf5b_row1_col3" class="data row1 col3" >0.2500</td>
#       <td id="T_fcf5b_row1_col4" class="data row1 col4" >0.8709</td>
#     </tr>
#     <tr>
#       <th id="T_fcf5b_level0_row2" class="row_heading level0 row2" >20250905_160232__cytotrace2-conda__gRlSz3gROJ</th>
#       <td id="T_fcf5b_row2_col0" class="data row2 col0" >104.1800</td>
#       <td id="T_fcf5b_row2_col1" class="data row2 col1" >2143248.0000</td>
#       <td id="T_fcf5b_row2_col2" class="data row2 col2" >0.9600</td>
#       <td id="T_fcf5b_row2_col3" class="data row2 col3" >0.2500</td>
#       <td id="T_fcf5b_row2_col4" class="data row2 col4" >0.8229</td>
#     </tr>
#     <tr>
#       <th id="T_fcf5b_level0_row3" class="row_heading level0 row3" >20250905_160424__palantir-conda__6cKPwZTMIl</th>
#       <td id="T_fcf5b_row3_col0" class="data row3 col0" >100.0900</td>
#       <td id="T_fcf5b_row3_col1" class="data row3 col1" >1151840.0000</td>
#       <td id="T_fcf5b_row3_col2" class="data row3 col2" >7.5100</td>
#       <td id="T_fcf5b_row3_col3" class="data row3 col3" >0.2500</td>
#       <td id="T_fcf5b_row3_col4" class="data row3 col4" >0.9577</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 现有指标计算问题：
#
# （1）计算太慢了（首要问题）
#
# （2）大部分指标计算为空，feature相关指标报错
