# %%
import cafe

# cafe.logger.setLevel("DEBUG")
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3

# %%
fadata = cafe.data.read_bonemarrow()
# cafe.plot.plot_trajectory(fadata)
fadata
# Out:
# AnnData object with n_obs × n_vars = 5780 × 27876
#     obs: 'clusters', 'palantir_pseudotime', 'palantir_diff_potential', 'raw_index'
#     var: 'palantir'
#     uns: 'clusters_colors', 'palantir_branch_probs_cell_types', 'id', 'cafe', 'filename'
#     obsm: 'MAGIC_imputed_data', 'X_tsne', 'palantir_branch_probs'
#     layers: 'spliced', 'unspliced', 'expression', 'counts'

# %%
from cafe.benchmark.util import generate_method_paramters 

generate_method_paramters(fadata)
# Out:
#                     use_gpu     backend_name
# paga                  False            conda
# comp1                 False            conda
# cluster_mst           False            conda
# state_comp            False            conda
# projection_mst        False            conda
# graph_mst             False            conda
# scvelo                False            conda
# velovi                 True            conda
# veloae                 True            conda
# dynamo                False            conda
# pyrovelocity           True            conda
# celldancer             True            conda
# unitvelo               True            conda
# cytotrace2             True            conda
# palantir              False            conda
# sctc                  False            conda
# cellrank              False            conda
# stavia                False            conda
# ti_paga               False  dynverse_docker
# ti_slingshot          False  dynverse_docker
# ...

# %%
cafe.benchmark.run(fadata)
# Out:
# INFO     |- no method_parameter_dict or method_yaml_file provided, use default method yaml file(./.cafe/bonemarrow/benchmark/methods.yaml)
# INFO     |- load method_parameter_dict from yaml file './.cafe/bonemarrow/benchmark/methods.yaml'
# INFO     |- running method: angle with params: {'benchmark_resource': True}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cafe.benchmark.run(fadata)
#
# File ~/PyCode/scRNA/CellFateExplorer/cafe-release/cafe/benchmark/run.py:58, in run(fadata, method_parameter_dict, method_yaml_file, load_cached)
#      56 # run the method with given parameters
#      57 method = FateMethod(method_name=method_name)
# ---> 58 method.infer_trajectory(fadata, parameters=parameters, id=method_name)
#      59 plot_trajectory(fadata, save=True)  # calculate waypoint and visualization
# ...
