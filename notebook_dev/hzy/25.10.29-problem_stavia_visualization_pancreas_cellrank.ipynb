# %%
import cafe

cafe.logger.setLevel("DEBUG")
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3

# %%
# model_name = "stavia_problem"
model_name = "stavia_problem_prune" # 剪枝了的
fadata = cafe.data.read_pancrease_cellrank()
fadata.load_trajectory_dict(model_name_list=[model_name])
fadata
# Out:
# DEBUG    |- Reading data from '/root/PyCode/scRNA/data/Pancreas/endocrinogenesis_day15.5_velocity_kernel.h5ad'...

# %%
cafe.plot.plot_trajectory(fadata, model_name=model_name)
# cafe.plot.plot_wrapper(fadata, model_name=model_name, wrapper_type="velocity")
fadata
# Out:
# DEBUG    |- extract 'clusters' from prior infomation as parameter 'color'
# DEBUG    |- extract 'X_umap' from prior infomation as parameter 'basis'
# DEBUG    |- plot_trajectory for model_name:'stavia_problem_prune', color:'clusters'
# DEBUG    |- 'stavia_problem_prune' is not a valid random_time_string, don't need parse
# AnnData object with n_obs × n_vars = 2531 × 5974
#     obs: 'day', 'proliferation', 'G2M_score', 'S_score', 'phase', 'clusters_coarse', 'clusters', 'clusters_fine', 'louvain_Alpha', 'louvain_Beta', 'palantir_pseudotime', 'initial_size_unspliced', 'initial_size_spliced', 'initial_size', 'n_counts', 'raw_index'
# ...

# %%
cafe.plot.plot_graph(fadata, model_name=model_name)
# Out:
# DEBUG    |- calculate new milestone embedding for model_name:stavia_problem_prune.
# WARNING  |- cell number mismatch when plot graph for model 'stavia_problem_prune', skip this model.
# DEBUG    |- 'stavia_problem_prune' is not a valid random_time_string, don't need parse
# array([[<Axes: title={'center': 'stavia_problem_prune(clusters)'}, xlabel='_milestone_network_emb1', ylabel='_milestone_network_emb2'>]],
#       dtype=object)

# %%
# cafe.plot.plot_wrapper(fadata, model_name=model_name, wrapper_type="cluster")
# # cafe.plot.plot_wrapper(fadata, model_name=model_name, wrapper_type="cluster", mode="pie") # 参考stavia

# %%
# cafe.plot.plot_stream(fadata, model_name=model_name, mode="density")

# %%
cafe.plot.plot_pie(fadata, model_name=model_name, node_size_scale=3)
# Out:
# <Axes: title={'center': 'stavia_problem_prune (clusters)'}>
