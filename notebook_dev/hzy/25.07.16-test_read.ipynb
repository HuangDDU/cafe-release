# %%
import scanpy as sc

# 对象写入后无法在新环境直接读取
fadata = sc.read("test_write.h5ad")
fadata
# Out:
# ---------------------------------------------------------------------------
# IORegistryError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 import scanpy as sc
# ----> 3 fadata =  sc.read("test_write.h5ad")
#       4 fadata
#
# File ~/.conda/envs/cfe/lib/python3.10/site-packages/legacy_api_wrap/__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File ~/.conda/envs/cfe/lib/python3.10/site-packages/scanpy/readwrite.py:143, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     141 filename = Path(filename)  # allow passing strings
# ...

# %%
fadata = sc.read("test_write_h5ad.h5ad")
fadata
# Out:
# AnnData object with n_obs × n_vars = 6 × 2
#     obs: 'clusters'
#     uns: 'cfe'
#     obsm: 'X_emb'
#     layers: 'counts', 'expression'
