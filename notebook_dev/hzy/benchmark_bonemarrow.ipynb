# %%
import cafe

cafe.logger.setLevel("DEBUG")
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3

# %%
fadata = cafe.data.read_bonemarrow()
cafe.plot.plot_trajectory(fadata)
fadata.id
# Out:
# DEBUG    |- Reading data from '/root/PyCode/scRNA/data/BoneMarrow/setty_bone_marrow.h5ad'...
# DEBUG    |- transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
# DEBUG    |- Create a FateAnnData object from an existing AnnData object.
# DEBUG    |- recognizing prior information...
# DEBUG    |--- recognize 'clusters' in '.obs' columns as 'cluster' key
# DEBUG    |--- recognize 'X_tsne' in '.obsm' keys as 'basis' key
# DEBUG    |- Created directory: '.cafe/bonemarrow/log'
# DEBUG    |- Created directory: '.cafe/bonemarrow/trajectory_history'
# DEBUG    |- Created directory: '.cafe/bonemarrow/metric'
# DEBUG    |- Created directory: '.cafe/bonemarrow/h5ad'
# DEBUG    |- Created directory: '.cafe/bonemarrow/img'
# DEBUG    |- add prior information...
# DEBUG    |- FateAnnData add_trajectory
# DEBUG    |- synchronize milestone color with reference color dict.
# DEBUG    |- extract 'clusters' from prior infomation as parameter 'color'
# ...
