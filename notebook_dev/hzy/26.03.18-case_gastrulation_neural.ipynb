# %%
import pandas as pd
import cafe

cafe.logger.setLevel("DEBUG")
img_dir = "./img/26.03.18-case_gastrulation_neural"
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3

# %%
sub_filename = ".cafe/gastrulation_neural/h5ad/gastrulation_neural.h5ad"
fadata = cafe.data.read_h5ad(sub_filename)
fadata.prior_information["basis"]="X_umap"
fadata
# Out:
# DEBUG    |- Create a FateAnnData object from an existing AnnData object.
# DEBUG    |- recognizing prior information...
# DEBUG    |--- recognize 'celltype' in '.obs' columns as 'cluster' key
# DEBUG    |--- recognize 'X_umap' in '.obsm' keys as 'basis' key
# DEBUG    |- unserialize trajectory dict: 'ref_coarse_cluster'
# DEBUG    |- parse 'MilestoneWrapper' object for ref_coarse_cluster
# DEBUG    |- unserialize trajectory dict: 'ref_coarse_projection'
# DEBUG    |- parse 'MilestoneWrapper' object for ref_coarse_projection
# AnnData object with n_obs × n_vars = 9724 × 53801
#     obs: 'barcode', 'sample', 'stage', 'sequencing.batch', 'theiler', 'doub.density', 'doublet', 'cluster', 'cluster.sub', 'cluster.stage', 'cluster.theiler', 'stripped', 'celltype', 'colour', 'umapX', 'umapY', 'haem_gephiX', 'haem_gephiY', 'haem_subclust', 'endo_gephiX', 'endo_gephiY', 'endo_trajectoryName', 'endo_trajectoryDPT', 'endo_gutX', 'endo_gutY', 'endo_gutDPT', 'endo_gutCluster', 'cell_velocyto_loom', 'celltype_coarse', 'celltype_new', 'pseudotime'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     uns: 'cafe', 'celltype_coarse_colors', 'celltype_colors', 'celltype_new_colors', 'id'
#     obsm: 'X_pca', 'X_stavia', 'X_umap'
#     layers: 'spliced', 'unspliced'

# %%
milestone_network = pd.DataFrame(
    [
        ["NMP", "Spinal cord"], # NMP全称为Neural Mesoderm Progenitor
        ["NMP", "Neural crest"],
        # weak edge
        # ["NMP", "Forebrain/Midbrain/Hindbrain"],
        # ["NMP", "Notochord"],
    ],
    columns=["from", "to"],
)

fadata.add_trajectory_mannually(milestone_network=milestone_network)
# Out:
# INFO     |- discrete milestones: ['Forebrain/Midbrain/Hindbrain', 'Notochord']
# WARNING  |- Both milestone_percentages and progressions are given, will only use progressions
# WARNING  |- Both milestone_percentages and progressions are given, will only use progressions
# DEBUG    |- FateAnnData add_trajectory
# DEBUG    |- synchronize milestone color with reference color dict.

# %%
cafe.plot.plot_trajectory(fadata)
cafe.plot.plot_graph(fadata)
# Out:
# DEBUG    |- extract 'celltype' from prior infomation as parameter 'color'
# DEBUG    |- extract 'X_umap' from prior infomation as parameter 'basis'
# DEBUG    |- calculate new trajectory embedding for model_name:ref, basis:X_umap.
# DEBUG    |- add waypoints
# DEBUG    |- FateAnnData add_waypoints
# DEBUG    |- add waypoints shape is (205, 9724) for 'ref', finished!
# DEBUG    |- plot_trajectory for model_name:'ref', color:'celltype'
# DEBUG    |- 'ref' is not a valid random_time_string, don't need parse
# DEBUG    |- calculate new milestone embedding for model_name:ref.
# DEBUG    |- 'ref' is not a valid random_time_string, don't need parse
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 cafe.plot.plot_trajectory(fadata)
# ----> 2 cafe.plot.plot_graph(fadata)
#
# File ~/PyCode/scRNA/CellFateExplorer/cafe-release/cafe/plot/plot_graph.py:179, in plot_graph(fadata, model_name, color, layout_by_row, nx_draw_kwargs, recompute_milestone_embedding, adjust_edge_length_for_layout, edge_length_range, layout_rankdir, layout_ranksep, layout_nodesep, save, **sc_pl_embedding_kwargs)
#     177 # TODO: nx plot keep unchange in the color loop, but it should plot for every ax.
#     178 milestone_color_dict = milestone_wrapper["milestone_color_dict"]
# --> 179 nx.draw(
#     180     G,
#     181     milestone_emb_dict,
#     182     with_labels=True,
#     183     node_color=[milestone_color_dict[node] for node in G.nodes],
#     184     width=5,
#     185     edge_color="gray",
#     186     arrowstyle="simple",
#     187     arrowsize=30,
#     188     ax=ax,
#     189     **nx_draw_kwargs,
#     190 )
#     191 if divergence_regions.shape[0] > 0:
#     192     plot_divergence_region(divergence_regions, milestone_emb_dict, ax=ax)  # divergence regoin
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:126, in draw(G, pos, ax, **kwds)
#     123 if "with_labels" not in kwds:
#     124     kwds["with_labels"] = "labels" in kwds
# --> 126 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127 ax.set_axis_off()
#     128 plt.draw_if_interactive()
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:315, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     312     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     314 draw_networkx_nodes(G, pos, **node_kwds)
# --> 315 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     316 if with_labels:
#     317     draw_networkx_labels(G, pos, **label_kwds)
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:1061, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin, hide_ticks)
#    1059     for i in range(len(edgelist)):
#    1060         arrow = fancy_arrow_factory(i)
# -> 1061         ax.add_patch(arrow)
#    1062         edge_viz_obj.append(arrow)
#    1064 # update view after drawing
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/matplotlib/axes/_base.py:2414, in _AxesBase.add_patch(self, p)
#    2412 if p.get_clip_path() is None:
#    2413     p.set_clip_path(self.patch)
# -> 2414 self._update_patch_limits(p)
#    2415 self._children.append(p)
#    2416 p._remove_method = self._children.remove
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/matplotlib/axes/_base.py:2432, in _AxesBase._update_patch_limits(self, patch)
#    2429 if (isinstance(patch, mpatches.Rectangle) and
#    2430         ((not patch.get_width()) and (not patch.get_height()))):
#    2431     return
# -> 2432 p = patch.get_path()
#    2433 # Get all vertices on the path
#    2434 # Loop through each segment to get extrema for Bezier curve sections
#    2435 vertices = []
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/matplotlib/patches.py:4408, in FancyArrowPatch.get_path(self)
#    4405 """Return the path of the arrow in the data coordinates."""
#    4406 # The path is generated in display coordinates, then converted back to
#    4407 # data coordinates.
# -> 4408 _path, fillable = self._get_path_in_displaycoord()
#    4409 if np.iterable(fillable):
#    4410     _path = Path.make_compound_path(*_path)
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/matplotlib/patches.py:4430, in FancyArrowPatch._get_path_in_displaycoord(self)
#    4427 else:
#    4428     _path = self.get_transform().transform_path(self._path_original)
# -> 4430 _path, fillable = self.get_arrowstyle()(
#    4431     _path,
#    4432     self.get_mutation_scale() * dpi_cor,
#    4433     self.get_linewidth() * dpi_cor,
#    4434     self.get_mutation_aspect())
#    4436 return _path, fillable
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/matplotlib/patches.py:3260, in ArrowStyle._Base.__call__(self, path, mutation_size, linewidth, aspect_ratio)
#    3258 path_shrunk = Path(vertices, path.codes)
#    3259 # call transmute method with squeezed height.
# -> 3260 path_mutated, fillable = self.transmute(path_shrunk,
#    3261                                         mutation_size,
#    3262                                         linewidth)
#    3263 if np.iterable(fillable):
#    3264     # Restore the height
#    3265     path_list = [Path(p.vertices * [1, aspect_ratio], p.codes)
#    3266                  for p in path_mutated]
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/matplotlib/patches.py:3684, in ArrowStyle.Simple.transmute(self, path, mutation_size, linewidth)
#    3682 def transmute(self, path, mutation_size, linewidth):
#    3683     # docstring inherited
# -> 3684     x0, y0, x1, y1, x2, y2 = self.ensure_quadratic_bezier(path)
#    3686     # divide the path into a head and a tail
#    3687     head_length = self.head_length * mutation_size
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/matplotlib/patches.py:3230, in ArrowStyle._Base.ensure_quadratic_bezier(path)
#    3227 segments = list(path.iter_segments())
#    3228 if (len(segments) != 2 or segments[0][1] != Path.MOVETO or
#    3229         segments[1][1] != Path.CURVE3):
# -> 3230     raise ValueError(
#    3231         "'path' is not a valid quadratic Bezier curve")
#    3232 return [*segments[0][0], *segments[1][0]]
#
# ValueError: 'path' is not a valid quadratic Bezier curve

# %%
fadata.id = "gastrulation_neural"
fadata.check_result_dir()
fadata.write_trajectory_dict(model_name_list=["ref"])
# Out:
# DEBUG    |- write trajectory 'ref' to './.cafe/gastrulation_neural/trajectory_history/ref.pkl'
