# %% [markdown]
# test pip package "cafe" installation based on colab

# %%
# 参考 
! python --version

! sudo update-alternatives --config python3 # 此处在Colab的网页版本可以选择，但是这里暂时不好搞
! apt-get update
! apt-get install python3-pip

! python --version
# Out:
# /usr/local/bin/python
