# %%
import cafe

# cafe.logger.setLevel("DEBUG")
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3

# %%
cafe.settings.backend = "conda"
method_name_list = [
    "scvelo",
    "celldancer",
]
for method_name in method_name_list:
    method = cafe.method.FateMethod(method_name=method_name)
    method.choose_backend()
    method.method_backend.test_conda_env()
    # method.method_backend.export_conda_env(export_dir="./env", format="tar.gz")
    method.method_backend.generate_dockerfile()
# Out:
# INFO     |- method backend loaded: CondaBackend: scvelo in conda env 'cafe'
# INFO     |- cafe conda env, don'n need to generate external conda environment file.
# INFO     |- cafe conda env, can't generate dockerfile automatically, need to add it manually.
# INFO     |- method backend loaded: CondaBackend: celldancer in conda env 'celldancer'
# ERROR    |- failed to export conda environment 'celldancer'.
# INFO     |- write dockerfile base template.dockerfile to '/root/PyCode/scRNA/CellFateExplorer/cafe-release/cafe/method/Dockerfile/celldancer.dockerfile'
# WARNING  |- GPU packages detected, please ensure to choose appropriate CUDA base image in the generated Dockerfile.
