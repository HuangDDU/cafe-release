# %%
import cfe
import scanpy as sc

cfe.settings.backend = "conda"
cfe.logger.setLevel("INFO")
# Out:
# [07/16/2025 11:02:24] INFO
#                                   _____     _ _ ______    _       ______            _
#                                  / ____|   | | |  ____|  | |     |  ____|          | |
#                                 | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                 | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                 | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                  \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                              | |
#                                                                              |_|

# %% [markdown]
# 数据

# %%
cluster_key = "clusters"
fadata = cfe.data.read_pancrease(n_obs=500 ,save_cluster_key=cluster_key)
fadata
# Out:
# AnnData object with n_obs × n_vars = 500 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     uns: 'cfe'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced', 'expression', 'count'

# %%
cluster_key = "milestone_color"
fadata.group_onto_nearest_milestones(cluster_key=cluster_key) # new cluster color

basis = "umap"
cluster_key_list = ["milestone", cluster_key]
cfe.plot.plot_graph(fadata, color=cluster_key_list)
cfe.plot.plot_trajectory(fadata, basis=basis, color=cluster_key_list)
# Out:
# <Axes: title={'center': 'milestone_color'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
prior_information = {}
fadata.add_prior_information(**prior_information)  # add prior information to fadata
parameters = {}

method_name_list = ["scvelo"]

for method_name in method_name_list:
    method = cfe.method.FateMethod(method_name=method_name)
    method.infer_trajectory(fadata, parameters=parameters)
    # TODO: 细胞太少会报错
    cfe.plot.plot_trajectory(fadata, basis=basis, color=cluster_key_list)
# Out:
# [07/16/2025 11:02:30] INFO     method_backend: <cfe.method.fate_conda_backend.CondaBackend object at 0x780a71e4c670>
#                       WARNING
#                                                Prior information groups_id is optional, but missing from dataset 20250716_110225__FateAnnData__KkCar0tpxd.
#
#                                                Will not give this prior to method.
#
# [07/16/2025 11:02:32] INFO     [stdout]Filtered out 24818 genes that are detected 20 counts (shared).
#                       INFO     [stdout]Normalized count data: X, spliced, unspliced.
# [07/16/2025 11:02:33] INFO     [stdout]Extracted 2000 highly variable genes.
#                       INFO     [stdout]Logarithmized X.
#                       INFO     [stdout]computing neighbors
# [07/16/2025 11:02:35] INFO     [stdout]    finished (0:00:02) --> added
#                       INFO     [stdout]    'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
#                       INFO     [stdout]computing moments based on connectivities
#                       INFO     [stdout]    finished (0:00:00) --> added
#                       INFO     [stdout]    'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#                       INFO     [stdout]computing velocities
#                       INFO     [stdout]    finished (0:00:00) --> added
#                       INFO     [stdout]    'velocity', velocity vectors for each individual cell (adata.layers)
#                       INFO     [stdout]computing velocity graph (using 1/24 cores)
#                       INFO     [stdout]  0%|          | 0/500 [00:00<?, ?cells/s]
# [07/16/2025 11:02:36] INFO     [stdout]    finished (0:00:00) --> added
#                       INFO     [stdout]    'velocity_graph', sparse matrix with cosine correlations (adata.uns)
#                       INFO     [stdout]cf_scvelo finish!
# WARNING: The neighbor graph has an unexpected format (e.g. computed outside scvelo)
# or is corrupted (e.g. due to subsetting). Consider recomputing with `pp.neighbors`.
# computing terminal states
#     identified 1 region of root cells and 1 region of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# running PAGA using priors: ['velocity_pseudotime']
#     finished (0:00:00) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
cfe.plot.plot_graph(fadata, color=cluster_key_list)
cfe.plot.plot_wrapper(fadata)
# Out:
# [07/16/2025 11:02:40] INFO     find wrapper type: velocity
