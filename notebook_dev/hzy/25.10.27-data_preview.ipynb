# %%
import cfe

cfe.logger.setLevel("DEBUG")
# Out:
# [10/27/2025 11:29:57] INFO
#                                   _____     _ _ ______    _       ______            _
#                                  / ____|   | | |  ____|  | |     |  ____|          | |
#                                 | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                 | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                 | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                  \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                              | |
#                                                                              |_|

# %%
fadata = cfe.data.read_bonemarrow()
cfe.plot.plot_trajectory(fadata)
fadata.id
# Out:
#                       DEBUG    Reading data from '/root/PyCode/scRNA/data/BoneMarrow/setty_bone_marrow.h5ad'...
#                       DEBUG    transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
# [10/27/2025 11:29:58] DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_tsne' in '.obsm' keys as 'basis' key
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    extract 'clusters' from prior infomation as parameter 'color'
#                       DEBUG    extract 'X_tsne' from prior infomation as parameter 'basis'
#                       DEBUG    calculate new trajectory embedding for model_name:ref, basis:X_tsne.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:30:03] DEBUG    add waypoints shape is (215, 5780) for 'ref', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    'ref' is not a valid random_time_string, don't need parse
# 'bonemarrow'

# %%
fadata = cfe.data.read_erythroid_lineage()
cfe.plot.plot_trajectory(fadata)
# Out:
# [10/27/2025 11:30:07] DEBUG    Reading data from '/root/PyCode/scRNA/data/Gastrulation/erythroid_lineage.h5ad'...
# [10/27/2025 11:30:08] DEBUG    transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'celltype' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    FateAnnData add_trajectory
# [10/27/2025 11:30:09] DEBUG    extract 'celltype' from prior infomation as parameter 'color'
#                       DEBUG    extract 'X_umap' from prior infomation as parameter 'basis'
#                       DEBUG    calculate new trajectory embedding for model_name:ref, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:30:19] DEBUG    add waypoints shape is (205, 9815) for 'ref', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    'ref' is not a valid random_time_string, don't need parse
# <Axes: title={'center': 'ref(celltype)'}, xlabel='X_umap1', ylabel='X_umap2'>

# %%
fadata = cfe.data.read_pancrease()
cfe.plot.plot_trajectory(fadata)
fadata.id
# Out:
#                       DEBUG    Reading data from '/root/PyCode/scRNA/data/Pancreas/endocrinogenesis_day15.h5ad'...
# [10/27/2025 11:30:20] DEBUG    transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    add prior information 'start_cell': 'cell_1103'
#                       DEBUG    FateAnnData add_trajectory
# [10/27/2025 11:30:21] DEBUG    extract 'clusters' from prior infomation as parameter 'color'
#                       DEBUG    extract 'X_umap' from prior infomation as parameter 'basis'
#                       DEBUG    calculate new trajectory embedding for model_name:ref, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:30:24] DEBUG    add waypoints shape is (212, 3696) for 'ref', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    'ref' is not a valid random_time_string, don't need parse
# 'pancreas'

# %%
fadata = cfe.data.read_pancrease_cellrank()
cfe.plot.plot_trajectory(fadata)
# Out:
#                       DEBUG    Reading data from '/root/PyCode/scRNA/data/Pancreas/endocrinogenesis_day15.5_velocity_kernel.h5ad'...
# [10/27/2025 11:16:35] DEBUG    transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
# [10/27/2025 11:16:36] DEBUG    FateAnnData add_trajectory
#                       DEBUG    extract 'clusters' from prior infomation as parameter 'color'
#                       DEBUG    extract 'X_umap' from prior infomation as parameter 'basis'
#                       DEBUG    calculate new trajectory embedding for model_name:ref, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [10/27/2025 11:16:38] DEBUG    add waypoints shape is (209, 2531) for 'ref', finished!
#                       DEBUG    plot_trajectory
#                       DEBUG    'ref' is not a valid random_time_string, don't need parse
# <Axes: title={'center': 'ref(clusters)'}, xlabel='X_umap1', ylabel='X_umap2'>
