# %%
import cfe

cfe.logger.setLevel("DEBUG")

# cfe.settings.backend = "cfe_docker"
cfe.settings.backend = "conda"
# Out:
# [09/28/2025 03:48:41] INFO
#                                   _____     _ _ ______    _       ______            _
#                                  / ____|   | | |  ____|  | |     |  ____|          | |
#                                 | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                 | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                 | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                  \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                              | |
#                                                                              |_|

# %%
fadata = cfe.data.read_pancrease()

fadata = cfe.data.read_h5ad("../../tests/data/pancrease_scvelo_500_fadata.h5ad")
fadata.add_prior_information(start_cell="cell_000")

fadata
# Out:
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    parse 'MilestoneWrapper' object for ref
# AnnData object with n_obs × n_vars = 500 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     uns: 'cfe'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'count', 'expression', 'spliced', 'unspliced'

# %%
method = cfe.method.FateMethod(method_name="dynamo")
method.infer_trajectory(fadata, parameters={"repreprocess": True})
# Out:
#                       DEBUG    CondaBackend __init__
# [09/28/2025 03:48:42] DEBUG    Conda environment 'dynamo' is available: Python 3.10.18
# [09/28/2025 03:48:44] DEBUG    Loaded function 'dynamo': <function dynamo at 0x7294077c9d80>
#                       INFO     method backend loaded: CondaBackend: dynamo in conda env 'dynamo'
#                       DEBUG    merged parameters: {'repreprocess': True}
#                       DEBUG    Temp wd: /tmp/tmpiwfamh8_
#                       INFO     cmd: conda run -n dynamo --no-capture-output python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py --function_name=dynamo
#                                --adata_path=/tmp/tmpiwfamh8_/adata.h5ad --parameters=/tmp/tmpiwfamh8_/parameters.json --output_filename=/tmp/tmpiwfamh8_/output.pkl
# [09/28/2025 03:48:48] INFO     [stdout]|-----> Running monocle preprocessing pipeline...
#                       INFO     [stdout]|-----------> filtered out 0 outlier cells
#                       INFO     [stdout]|-----------> filtered out 25527 outlier genes
# [09/28/2025 03:48:50] INFO     [stdout]|-----> PCA dimension reduction
#                       INFO     [stdout]|-----> <insert> X_pca to obsm in AnnData Object.
#                       INFO     [stdout]|-----> [Preprocessor-monocle] completed [1.7844s]
#                       INFO     [stdout]|-----> retrieve data for non-linear dimension reduction...
#                       INFO     [stdout]|-----? adata already have basis umap. dimension reduction umap will be skipped!
#                       INFO     [stdout]set enforce=True to re-performing dimension reduction.
#                       INFO     [stdout]|-----> Start computing neighbor graph...
#                       INFO     [stdout]|-----------> X_data is None, fetching or recomputing...
#                       INFO     [stdout]|-----> fetching X data from layer:None, basis:pca
#                       INFO     [stdout]|-----> method arg is None, choosing methods automatically...
#                       INFO     [stdout]|-----------> method ball_tree selected
#                       INFO     [stdout]|-----> [UMAP] completed [0.0225s]
#                       INFO     [stdout]|-----> dynamics_del_2nd_moments_key is None. Using default value from DynamoAdataConfig: dynamics_del_2nd_moments_key=False
#                       INFO     [stdout]|-----------> removing existing M layers:[]...
#                       INFO     [stdout]|-----------> making adata smooth...
#                       INFO     [stdout]|-----> calculating first/second moments...
# [09/28/2025 03:48:55] INFO     [stdout]|-----? layer X_expression is not in any of the (['X_spliced', 'X_unspliced'], ['X_new', 'X_total'], ['X_uu', 'X_ul', 'X_su', 'X_sl']) groups, skipping...
#                       INFO     [stdout]|-----? layer X_count is not in any of the (['X_spliced', 'X_unspliced'], ['X_new', 'X_total'], ['X_uu', 'X_ul', 'X_su', 'X_sl']) groups, skipping...
# [09/28/2025 03:48:56] INFO     [stdout]|-----? layer X_expression is not in any of the (['X_spliced', 'X_unspliced'], ['X_new', 'X_total'], ['X_uu', 'X_ul', 'X_su', 'X_sl']) groups, skipping...
#                       INFO     [stdout]|-----? layer X_count is not in any of the (['X_spliced', 'X_unspliced'], ['X_new', 'X_total'], ['X_uu', 'X_ul', 'X_su', 'X_sl']) groups, skipping...
#                       INFO     [stdout]|-----? layer X_expression is not in any of the (['X_spliced', 'X_unspliced'], ['X_new', 'X_total'], ['X_uu', 'X_ul', 'X_su', 'X_sl']) groups, skipping...
#                       INFO     [stdout]|-----? layer X_count is not in any of the (['X_spliced', 'X_unspliced'], ['X_new', 'X_total'], ['X_uu', 'X_ul', 'X_su', 'X_sl']) groups, skipping...
#                       INFO     [stdout]|-----> [moments calculation] completed [5.7955s]
#                       DEBUG    [stderr]
#                       DEBUG    [stderr]estimating gamma:   0%|          | 0/2000 [00:00<?, ?it/s]
#                       DEBUG    [stderr]estimating gamma:   2%|▏         | 41/2000 [00:00<00:04, 407.62it/s]
#                       DEBUG    [stderr]estimating gamma:   4%|▍         | 82/2000 [00:00<00:04, 386.18it/s]
#                       DEBUG    [stderr]estimating gamma:   6%|▌         | 121/2000 [00:00<00:05, 369.64it/s]
#                       DEBUG    [stderr]estimating gamma:   8%|▊         | 159/2000 [00:00<00:05, 355.36it/s]
#                       DEBUG    [stderr]estimating gamma:  10%|▉         | 195/2000 [00:00<00:05, 344.81it/s]
# [09/28/2025 03:48:57] DEBUG    [stderr]estimating gamma:  12%|█▏        | 230/2000 [00:00<00:05, 332.08it/s]
#                       DEBUG    [stderr]estimating gamma:  13%|█▎        | 264/2000 [00:00<00:05, 324.51it/s]
#                       DEBUG    [stderr]estimating gamma:  15%|█▍        | 297/2000 [00:00<00:05, 317.64it/s]
#                       DEBUG    [stderr]estimating gamma:  16%|█▋        | 329/2000 [00:00<00:05, 313.26it/s]
#                       DEBUG    [stderr]estimating gamma:  18%|█▊        | 361/2000 [00:01<00:05, 309.45it/s]
#                       DEBUG    [stderr]estimating gamma:  20%|█▉        | 392/2000 [00:01<00:05, 305.46it/s]
#                       DEBUG    [stderr]estimating gamma:  21%|██        | 423/2000 [00:01<00:05, 302.02it/s]
#                       DEBUG    [stderr]estimating gamma:  23%|██▎       | 454/2000 [00:01<00:05, 297.69it/s]
#                       DEBUG    [stderr]estimating gamma:  24%|██▍       | 484/2000 [00:01<00:05, 294.29it/s]
#                       DEBUG    [stderr]estimating gamma:  26%|██▌       | 514/2000 [00:01<00:05, 290.51it/s]
# [09/28/2025 03:48:58] DEBUG    [stderr]estimating gamma:  27%|██▋       | 544/2000 [00:01<00:05, 289.08it/s]
#                       DEBUG    [stderr]estimating gamma:  29%|██▊       | 573/2000 [00:01<00:04, 288.80it/s]
#                       DEBUG    [stderr]estimating gamma:  30%|███       | 602/2000 [00:01<00:04, 284.25it/s]
#                       DEBUG    [stderr]estimating gamma:  32%|███▏      | 631/2000 [00:02<00:04, 281.69it/s]
#                       DEBUG    [stderr]estimating gamma:  33%|███▎      | 660/2000 [00:02<00:04, 278.11it/s]
#                       DEBUG    [stderr]estimating gamma:  34%|███▍      | 689/2000 [00:02<00:04, 279.17it/s]
#                       DEBUG    [stderr]estimating gamma:  36%|███▌      | 717/2000 [00:02<00:04, 274.52it/s]
#                       DEBUG    [stderr]estimating gamma:  37%|███▋      | 745/2000 [00:02<00:04, 273.94it/s]
#                       DEBUG    [stderr]estimating gamma:  39%|███▊      | 773/2000 [00:02<00:04, 274.01it/s]
# [09/28/2025 03:48:59] DEBUG    [stderr]estimating gamma:  40%|████      | 801/2000 [00:02<00:04, 273.01it/s]
#                       DEBUG    [stderr]estimating gamma:  41%|████▏     | 829/2000 [00:02<00:04, 274.22it/s]
#                       DEBUG    [stderr]estimating gamma:  43%|████▎     | 857/2000 [00:02<00:04, 275.24it/s]
#                       DEBUG    [stderr]estimating gamma:  44%|████▍     | 885/2000 [00:02<00:04, 272.55it/s]
#                       DEBUG    [stderr]estimating gamma:  46%|████▌     | 913/2000 [00:03<00:04, 271.57it/s]
#                       DEBUG    [stderr]estimating gamma:  47%|████▋     | 941/2000 [00:03<00:03, 272.56it/s]
#                       DEBUG    [stderr]estimating gamma:  48%|████▊     | 969/2000 [00:03<00:03, 272.03it/s]
#                       DEBUG    [stderr]estimating gamma:  50%|████▉     | 997/2000 [00:03<00:03, 271.27it/s]
#                       DEBUG    [stderr]estimating gamma:  51%|█████▏    | 1025/2000 [00:03<00:03, 266.84it/s]
#                       DEBUG    [stderr]estimating gamma:  53%|█████▎    | 1052/2000 [00:03<00:03, 266.83it/s]
# [09/28/2025 03:49:00] DEBUG    [stderr]estimating gamma:  54%|█████▍    | 1080/2000 [00:03<00:03, 267.73it/s]
#                       DEBUG    [stderr]estimating gamma:  55%|█████▌    | 1107/2000 [00:03<00:03, 267.25it/s]
#                       DEBUG    [stderr]estimating gamma:  57%|█████▋    | 1134/2000 [00:03<00:03, 265.51it/s]
#                       DEBUG    [stderr]estimating gamma:  58%|█████▊    | 1162/2000 [00:04<00:03, 267.30it/s]
#                       DEBUG    [stderr]estimating gamma:  60%|█████▉    | 1190/2000 [00:04<00:03, 268.82it/s]
#                       DEBUG    [stderr]estimating gamma:  61%|██████    | 1217/2000 [00:04<00:02, 267.28it/s]
#                       DEBUG    [stderr]estimating gamma:  62%|██████▏   | 1244/2000 [00:04<00:02, 267.29it/s]
#                       DEBUG    [stderr]estimating gamma:  64%|██████▎   | 1271/2000 [00:04<00:02, 267.36it/s]
#                       DEBUG    [stderr]estimating gamma:  65%|██████▍   | 1298/2000 [00:04<00:02, 268.07it/s]
#                       DEBUG    [stderr]estimating gamma:  66%|██████▋   | 1325/2000 [00:04<00:02, 266.20it/s]
# [09/28/2025 03:49:01] DEBUG    [stderr]estimating gamma:  68%|██████▊   | 1352/2000 [00:04<00:02, 264.84it/s]
#                       DEBUG    [stderr]estimating gamma:  69%|██████▉   | 1379/2000 [00:04<00:02, 265.86it/s]
#                       DEBUG    [stderr]estimating gamma:  70%|███████   | 1406/2000 [00:04<00:02, 266.41it/s]
#                       DEBUG    [stderr]estimating gamma:  72%|███████▏  | 1433/2000 [00:05<00:02, 266.73it/s]
#                       DEBUG    [stderr]estimating gamma:  73%|███████▎  | 1460/2000 [00:05<00:02, 267.16it/s]
#                       DEBUG    [stderr]estimating gamma:  74%|███████▍  | 1488/2000 [00:05<00:01, 268.22it/s]
#                       DEBUG    [stderr]estimating gamma:  76%|███████▌  | 1515/2000 [00:05<00:01, 265.47it/s]
#                       DEBUG    [stderr]estimating gamma:  77%|███████▋  | 1542/2000 [00:05<00:01, 262.82it/s]
#                       DEBUG    [stderr]estimating gamma:  78%|███████▊  | 1569/2000 [00:05<00:01, 263.86it/s]
# [09/28/2025 03:49:02] DEBUG    [stderr]estimating gamma:  80%|███████▉  | 1597/2000 [00:05<00:01, 266.16it/s]
#                       DEBUG    [stderr]estimating gamma:  81%|████████▏ | 1625/2000 [00:05<00:01, 267.91it/s]
#                       DEBUG    [stderr]estimating gamma:  83%|████████▎ | 1653/2000 [00:05<00:01, 269.76it/s]
#                       DEBUG    [stderr]estimating gamma:  84%|████████▍ | 1681/2000 [00:05<00:01, 271.06it/s]
#                       DEBUG    [stderr]estimating gamma:  86%|████████▌ | 1710/2000 [00:06<00:01, 275.21it/s]
#                       DEBUG    [stderr]estimating gamma:  87%|████████▋ | 1739/2000 [00:06<00:00, 277.23it/s]
#                       DEBUG    [stderr]estimating gamma:  88%|████████▊ | 1767/2000 [00:06<00:00, 276.85it/s]
#                       DEBUG    [stderr]estimating gamma:  90%|████████▉ | 1795/2000 [00:06<00:00, 275.29it/s]
#                       DEBUG    [stderr]estimating gamma:  91%|█████████ | 1824/2000 [00:06<00:00, 278.31it/s]
#                       DEBUG    [stderr]estimating gamma:  93%|█████████▎| 1853/2000 [00:06<00:00, 281.24it/s]
# [09/28/2025 03:49:03] DEBUG    [stderr]estimating gamma:  94%|█████████▍| 1882/2000 [00:06<00:00, 282.15it/s]
#                       DEBUG    [stderr]estimating gamma:  96%|█████████▌| 1911/2000 [00:06<00:00, 281.90it/s]
#                       DEBUG    [stderr]estimating gamma:  97%|█████████▋| 1942/2000 [00:06<00:00, 289.77it/s]
#                       DEBUG    [stderr]estimating gamma:  99%|█████████▉| 1975/2000 [00:06<00:00, 299.24it/s]
#                       DEBUG    [stderr]estimating gamma: 100%|██████████| 2000/2000 [00:07<00:00, 284.20it/s]
#                       INFO     [stdout]
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 1.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 2.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 3.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 4.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 5.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 6.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 8.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 9.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 10.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 11.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 12.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 14.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 15.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 16.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 17.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 18.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 19.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 21.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 22.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 23.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 24.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 25.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 26.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 27.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 29.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 30.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 31.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 32.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 33.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 34.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 35.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 36.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 38.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 39.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 40.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 41.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 42.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 44.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 45.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 46.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 47.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 48.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 49.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 51.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 52.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 53.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 54.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 55.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 56.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 58.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 59.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 60.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 61.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 62.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 63.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 65.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 66.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 67.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 68.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 69.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 71.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 72.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 73.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 74.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 75.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 77.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 78.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 79.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 80.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 81.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 83.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 84.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 85.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 86.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 87.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 88.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 90.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 91.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 92.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 93.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 94.8000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 96.0000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 97.2000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 98.4000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 99.6000%
#                       INFO     [stdout]|-----> [calculating transition matrix via pearson kernel with sqrt transform.] in progress: 100.0000%|-----> [calculating transition matrix via pearson kernel
#                                with sqrt transform.] completed [0.1979s]
#                       INFO     [stdout]
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 1.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 2.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 3.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 4.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 5.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 6.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 8.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 9.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 10.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 11.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 12.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 14.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 15.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 16.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 17.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 18.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 19.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 21.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 22.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 23.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 24.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 25.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 26.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 27.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 29.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 30.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 31.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 32.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 33.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 34.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 35.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 36.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 38.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 39.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 40.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 41.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 42.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 44.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 45.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 46.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 47.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 48.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 49.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 51.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 52.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 53.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 54.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 55.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 56.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 58.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 59.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 60.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 61.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 62.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 63.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 65.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 66.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 67.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 68.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 69.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 71.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 72.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 73.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 74.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 75.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 77.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 78.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 79.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 80.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 81.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 83.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 84.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 85.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 86.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 87.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 88.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 90.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 91.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 92.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 93.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 94.8000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 96.0000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 97.2000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 98.4000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 99.6000%
#                       INFO     [stdout]|-----> [projecting velocity vector to low dimensional embedding] in progress: 100.0000%|-----> [projecting velocity vector to low dimensional embedding]
#                                completed [0.0396s]
#                       INFO     [stdout]|-----> method arg is None, choosing methods automatically...
#                       INFO     [stdout]|-----------> method kd_tree selected
#                       INFO     [stdout]computing velocity graph (using 1/24 cores)
#                       INFO     [stdout]  0%|          | 0/500 [00:00<?, ?cells/s]
# [09/28/2025 03:49:10] INFO     [stdout]    finished (0:00:06) --> added
#                       INFO     [stdout]    'velocity_graph', sparse matrix with cosine correlations (adata.uns)
#                       INFO     [stdout]dynamo finish!
# [09/28/2025 03:49:11] DEBUG    Conda finish
#                       DEBUG    Add trajectory by wrapper type: velocity
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    filterd adata: AnnData object with n_obs × n_vars = 500 × 27998
#                                    obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#                                    uns: 'cfe'
#                                    obsm: 'X_pca', 'X_umap'
#                                    layers: 'count', 'expression', 'spliced', 'unspliced'
#                       DEBUG    add raw velocity embedding to fadata
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# WARNING: The neighbor graph has an unexpected format (e.g. computed outside scvelo)
# or is corrupted (e.g. due to subsetting). Consider recomputing with `pp.neighbors`.
# computing terminal states
#     identified 1 region of root cells and 1 region of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# running PAGA using priors: ['velocity_pseudotime']
#     finished (0:00:00) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)
#                       DEBUG    milestone_network:             from            to  length  directed
#                                2    Ngn3 high EP        Ductal       1      True
#                                10   Ngn3 high EP   Ngn3 low EP       1      True
#                                19  Pre-endocrine  Ngn3 high EP       1      True
#                                35  Pre-endocrine          Beta       1      True
#                                43  Pre-endocrine         Alpha       1      True
#                                51  Pre-endocrine         Delta       1      True
#                       INFO     discrete milestones: ['Epsilon']
#                       DEBUG    FateAnnData add_trajectory
#                       INFO     method infer trajectory successfully: CondaBackend: dynamo in conda env 'dynamo'

# %%
# fix for isolated milestones and cells.
cfe.plot.plot_trajectory(fadata, color="clusters")
# Out:
#                       DEBUG    extract 'X_umap' from prior infomation as parameter 'basis'
#                       DEBUG    plot_trajectory
#                       DEBUG    calculate new trajectory embedding for model_name:None, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [09/28/2025 03:49:12] DEBUG    add waypoints shape is (211, 500) for 'None', finished!
# <Axes: title={'center': 'clusters'}, xlabel='X_umap1', ylabel='X_umap2'>
