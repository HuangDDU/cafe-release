# %%
import cafe

cafe.logger.setLevel("DEBUG")

# %%
cafe.method.scan_method(return_type="dataframe")
# Out:
#                   name version  \
# palantir      palantir   0.0.1
# comp1            comp1   0.0.1
# sctc              sctc   0.0.1
# cytotrace2  cytotrace2   0.0.1
# scvelo          scvelo   0.0.1
#
#                                                   description  \
# palantir    Palantir: characterization of cell fate probab...
# comp1       Comp1: baseline for linear wrapper, extract an...
# sctc             SCTC: single-Cell Transcriptional Complexity
# cytotrace2  Cytotrace2: cellular potency categories and ab...
# scvelo      scVelo: RNA velocity generalized through dynam...
#
#                               wrapper_type  \
# palantir    [linear, probability, lineage]
# comp1                               linear
# sctc                                linear
# cytotrace2                          linear
# scvelo                            velocity
#
#                                                     parameter
# palantir    {'adata': {'name': 'adata', 'default': None, '...
# ...
