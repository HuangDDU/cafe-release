# %% [markdown]
# # Benchmark

# %% [markdown]
# ## 1. Environment

# %%
import cfe
import scanpy as sc
import pandas as pd

# cfe.settings.backend = "python_function"
cfe.settings.backend = "conda"
cfe.logger.setLevel("DEBUG")
# cfe.logger.setLevel("INFO")
# Out:
# [09/10/2025 04:29:13] INFO
#                                   _____     _ _ ______    _       ______            _
#                                  / ____|   | | |  ____|  | |     |  ____|          | |
#                                 | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                 | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                 | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                  \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                              | |
#                                                                              |_|

# %% [markdown]
# ## 2. Data

# %%
# fadata = cfe.data.read_pancrease()
fadata = cfe.data.read_h5ad("../../tests/data/pancrease_scvelo_500_fadata.h5ad")
fadata
# Out:
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    parse 'MilestoneWrapper' object for ref
# AnnData object with n_obs × n_vars = 500 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     uns: 'cfe'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'count', 'expression', 'spliced', 'unspliced'

# %%
start_cell = "cell_000"
pseudotime_key = "trajectory_pseudotime"
fadata.obs[pseudotime_key] = fadata.get_trajectory_pseudotime(start_cell=start_cell)

cluster_key = "clusters"
cfe.plot.plot_trajectory(fadata, color=[cluster_key, pseudotime_key])
# Out:
#                       DEBUG    start_milestone is None,                 try to use start cell 'cell_000' to identify start milestone automatically
#                       DEBUG    find start milestone 'Ductal' from start cell 'cell_000'
#                       DEBUG    calculating new pseudotime
#                       DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_Ductal`
#                       DEBUG    plot_trajectory
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
#                       DEBUG    add waypoints shape is (210, 500), finished!
# <Axes: title={'center': 'trajectory_pseudotime'}, xlabel='UMAP1', ylabel='UMAP2'>

# %% [markdown]
# ## 3. Method

# %%
# # common preprocessing
# import scvelo as scv

# scv.pp.filter_and_normalize(fadata, min_shared_counts=20, n_top_genes=2000)
# scv.pp.moments(fadata, n_pcs=20, n_neighbors=10)
# fadata

# %%
# cluster_key = "clusters"
# cluster_key_list = ["milestone", cluster_key]

method2parameters = {
    # new method 
    "comp1": {
        "basis": "X_umap",
    },
    "cytotrace2":{
        # TODO: parameters need adjust, cytotrace need 
        # TODO: cluster_key need to be extract from prior information
        "repreprocess": True,
        "cluster_key": cluster_key,
        "cytotrace2_kwargs": {
            "max_cores": 8, # 使用并行并指定核数, 当细胞数较少时，建议减少核数否则会阻塞在分数平滑处
        }
    },
    "palantir": {
        "palantir_results_kwargs": {
            "early_cell": "cell_000",
        },
    },
    "sctc": {},
    
    # # old dynverse method
    "ti_comp1": {},
    "ti_scorpius":{},
    "ti_embeddr":{},
    # "ti_matcher":{},
    # "ti_tscan":{},
}

for method_name, parameters in method2parameters.items():
    parameters["benchmark_resource"] = True  # record resource usage
    method = cfe.method.FateMethod(method_name=method_name)
    method.infer_trajectory(fadata, parameters=parameters)
    # cfe.plot.plot_trajectory(fadata, basis="umap", color=cluster_key)
    
    # extract pseudotime and plot
    raw_wrapper_dict = fadata.get_raw_wrapper_dict()
    pseudotime_key = f"{method_name}_pseudotime"
    color_list = [cluster_key, pseudotime_key]
    if not raw_wrapper_dict == {}:
        # raw_wrapper_dict is available for conda or CFE docker
        fadata.obs[pseudotime_key] = raw_wrapper_dict["pseudotime"]
    else:
        # raw_wrapper_dict is not available for dynverse docker
        fadata.obs[pseudotime_key] = fadata.get_milestone_wrapper().progressions["percentage"].tolist()
        
    cfe.plot.plot_trajectory(fadata, basis="umap", color=color_list)
# Out:
# [09/10/2025 04:29:14] DEBUG    CondaBackend __init__
# [09/10/2025 04:29:15] DEBUG    Conda environment 'cfe' is available: Python 3.10.15
#                       INFO     method_backend: CondaBackend: function_name-cf_comp1, load_backend-cfe
#                       DEBUG    Temp wd: /tmp/tmpw6vkfsm6
#                       INFO     cmd: conda run -n cfe --no-capture-output /usr/bin/time -v python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_comp1 --adata_path=/tmp/tmpw6vkfsm6/adata.h5ad --prior_information=/tmp/tmpw6vkfsm6/prior_information.json
#                                --parameters=/tmp/tmpw6vkfsm6/parameters.json --output_filename=/tmp/tmpw6vkfsm6/output.pkl
# [09/10/2025 04:29:18] INFO     [stdout]cf_comp1 finish!
#                       DEBUG    [stderr]        Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py --function_name=cf_comp1
#                                --adata_path=/tmp/tmpw6vkfsm6/adata.h5ad --prior_information=/tmp/tmpw6vkfsm6/prior_information.json --parameters=/tmp/tmpw6vkfsm6/parameters.json
#                                --output_filename=/tmp/tmpw6vkfsm6/output.pkl"
#                       DEBUG    [stderr]        User time (seconds): 2.44
#                       DEBUG    [stderr]        System time (seconds): 2.70
#                       DEBUG    [stderr]        Percent of CPU this job got: 334%
#                       DEBUG    [stderr]        Elapsed (wall clock) time (h:mm:ss or m:ss): 0:01.53
#                       DEBUG    [stderr]        Average shared text size (kbytes): 0
#                       DEBUG    [stderr]        Average unshared data size (kbytes): 0
#                       DEBUG    [stderr]        Average stack size (kbytes): 0
#                       DEBUG    [stderr]        Average total size (kbytes): 0
#                       DEBUG    [stderr]        Maximum resident set size (kbytes): 664616
#                       DEBUG    [stderr]        Average resident set size (kbytes): 0
#                       DEBUG    [stderr]        Major (requiring I/O) page faults: 0
#                       DEBUG    [stderr]        Minor (reclaiming a frame) page faults: 103284
#                       DEBUG    [stderr]        Voluntary context switches: 106
#                       DEBUG    [stderr]        Involuntary context switches: 272
#                       DEBUG    [stderr]        Swaps: 0
#                       DEBUG    [stderr]        File system inputs: 0
#                       DEBUG    [stderr]        File system outputs: 16
#                       DEBUG    [stderr]        Socket messages sent: 0
#                       DEBUG    [stderr]        Socket messages received: 0
#                       DEBUG    [stderr]        Signals delivered: 0
#                       DEBUG    [stderr]        Page size (bytes): 4096
#                       DEBUG    [stderr]        Exit status: 0
#                       DEBUG    Conda finish
#                       DEBUG    resource usage string:  Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_comp1 --adata_path=/tmp/tmpw6vkfsm6/adata.h5ad --prior_information=/tmp/tmpw6vkfsm6/prior_information.json
#                                --parameters=/tmp/tmpw6vkfsm6/parameters.json --output_filename=/tmp/tmpw6vkfsm6/output.pkl"    User time (seconds): 2.44       System time (seconds): 2.70     Percent
#                                of CPU this job got: 334%       Elapsed (wall clock) time (h:mm:ss or m:ss): 0:01.53    Average shared text size (kbytes): 0    Average unshared data size (kbytes): 0
#                                Average stack size (kbytes): 0  Average total size (kbytes): 0  Maximum resident set size (kbytes): 664616      Average resident set size (kbytes): 0   Major (requiring
#                                I/O) page faults: 0    Minor (reclaiming a frame) page faults: 103284  Voluntary context switches: 106 Involuntary context switches: 272       Swaps: 0        File
#                                system inputs: 0   File system outputs: 16 Socket messages sent: 0 Socket messages received: 0     Signals delivered: 0    Page size (bytes): 4096 Exit status: 0
#                       DEBUG    resource usage dict: {'time': 1.53, 'memory': 649.04, 'cpu': 3.34}
#                       DEBUG    Add trajectory by wrapper type: linear
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    plot_trajectory
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [09/10/2025 04:29:19] DEBUG    add waypoints shape is (201, 500), finished!
#                       DEBUG    CondaBackend __init__
# [09/10/2025 04:29:20] DEBUG    Conda environment 'cytotrace2' is available: Python 3.10.18
#                       INFO     method_backend: CondaBackend: function_name-cf_cytotrace2, load_backend-cytotrace2
#                       DEBUG    Temp wd: /tmp/tmpqaa9gm5a
# [09/10/2025 04:29:21] INFO     cmd: conda run -n cytotrace2 --no-capture-output /usr/bin/time -v python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_cytotrace2 --adata_path=/tmp/tmpqaa9gm5a/adata.h5ad --prior_information=/tmp/tmpqaa9gm5a/prior_information.json
#                                --parameters=/tmp/tmpqaa9gm5a/parameters.json --output_filename=/tmp/tmpqaa9gm5a/output.pkl
# [09/10/2025 04:29:24] INFO     [stdout]write expression matrix((27998, 500)) to  /tmp/tmpazgxzouu/cytotrace2_expression.csv
# [09/10/2025 04:29:26] INFO     [stdout]write annotation to /tmp/tmpazgxzouu/cytotrace2_annotations.csv
#                       INFO     [stdout]cytotrace2: Input parameters
#                       INFO     [stdout]    Input file: /tmp/tmpazgxzouu/cytotrace2_expression.csv
#                       INFO     [stdout]    Species: mouse
#                       INFO     [stdout]    Parallelization enabled: True
#                       INFO     [stdout]    Batch size: 20000
#                       INFO     [stdout]    Smoothing batch size: 1000
#                       INFO     [stdout]    Seed: 14
#                       INFO     [stdout]    Output directory: cytotrace2_results
#                       INFO     [stdout]    Plotting enabled: False
#                       INFO     [stdout]    Verbose mode enabled: True
#                       INFO     [stdout]    User-provided limit for number of cores to use: 8
#                       INFO     [stdout]cytotrace2: Loading dataset
#                       INFO     [stdout]cytotrace2: Dataset characteristics
#                       INFO     [stdout]    Number of input genes:  27998
#                       INFO     [stdout]    Number of input cells:  500
#                       INFO     [stdout]cytotrace2: The passed batch_size is greater than the number of cells in the subsample.
#                       INFO     [stdout]    Now setting batch_size to 500.
#                       INFO     [stdout]cytotrace2: Preprocessing
#                       INFO     [stdout]cytotrace2: The number of cells in your dataset is less than the specified smoothing batch size.
#                       INFO     [stdout]
#                       INFO     [stdout]    Model prediction will not be parallelized.
#                       INFO     [stdout]cytotrace2: Running 1 prediction batch(es) sequentially using 1 cores per batch.
#                       INFO     [stdout]cytotrace2: Initiated processing batch 1/1 with 500 cells
# [09/10/2025 04:29:30] INFO     [stdout]    14247 input genes are present in the model features.
#                       INFO     [stdout]cytotrace2: Performing initial model prediction
# [09/10/2025 04:29:45] INFO     [stdout]cytotrace2: Performing smoothing by diffusion
#                       INFO     [stdout]The passed subsample size is greater than the number of cells in the subsample.
#                       INFO     [stdout]    Now setting subsample size to 500.
#                       INFO     [stdout]cytotrace2: Performing smoothing by adaptive KNN
# [09/10/2025 04:29:47] INFO     [stdout]cytotrace2: Plotting disabled
#                       INFO     [stdout]cytotrace2: Finished.
#                       INFO     [stdout]cf_cytotrace2 finish!
#                       DEBUG    [stderr]        Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py --function_name=cf_cytotrace2
#                                --adata_path=/tmp/tmpqaa9gm5a/adata.h5ad --prior_information=/tmp/tmpqaa9gm5a/prior_information.json --parameters=/tmp/tmpqaa9gm5a/parameters.json
#                                --output_filename=/tmp/tmpqaa9gm5a/output.pkl"
#                       DEBUG    [stderr]        User time (seconds): 26.20
#                       DEBUG    [stderr]        System time (seconds): 1.68
#                       DEBUG    [stderr]        Percent of CPU this job got: 110%
#                       DEBUG    [stderr]        Elapsed (wall clock) time (h:mm:ss or m:ss): 0:25.14
#                       DEBUG    [stderr]        Average shared text size (kbytes): 0
#                       DEBUG    [stderr]        Average unshared data size (kbytes): 0
#                       DEBUG    [stderr]        Average stack size (kbytes): 0
#                       DEBUG    [stderr]        Average total size (kbytes): 0
#                       DEBUG    [stderr]        Maximum resident set size (kbytes): 2074136
#                       DEBUG    [stderr]        Average resident set size (kbytes): 0
#                       DEBUG    [stderr]        Major (requiring I/O) page faults: 0
#                       DEBUG    [stderr]        Minor (reclaiming a frame) page faults: 1414932
#                       DEBUG    [stderr]        Voluntary context switches: 1011
#                       DEBUG    [stderr]        Involuntary context switches: 381
#                       DEBUG    [stderr]        Swaps: 0
#                       DEBUG    [stderr]        File system inputs: 0
#                       DEBUG    [stderr]        File system outputs: 124536
#                       DEBUG    [stderr]        Socket messages sent: 0
#                       DEBUG    [stderr]        Socket messages received: 0
#                       DEBUG    [stderr]        Signals delivered: 0
#                       DEBUG    [stderr]        Page size (bytes): 4096
#                       DEBUG    [stderr]        Exit status: 0
#                       DEBUG    Conda finish
#                       DEBUG    resource usage string:  Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_cytotrace2 --adata_path=/tmp/tmpqaa9gm5a/adata.h5ad --prior_information=/tmp/tmpqaa9gm5a/prior_information.json
#                                --parameters=/tmp/tmpqaa9gm5a/parameters.json --output_filename=/tmp/tmpqaa9gm5a/output.pkl"       User time (seconds): 26.20      System time (seconds): 1.68
#                                Percent of CPU this job got: 110%       Elapsed (wall clock) time (h:mm:ss or m:ss): 0:25.14    Average shared text size (kbytes): 0    Average unshared data size
#                                (kbytes): 0  Average stack size (kbytes): 0  Average total size (kbytes): 0  Maximum resident set size (kbytes): 2074136     Average resident set size (kbytes): 0
#                                Major (requiring I/O) page faults: 0    Minor (reclaiming a frame) page faults: 1414932 Voluntary context switches: 1011        Involuntary context switches: 381
#                                Swaps: 0        File system inputs: 0   File system outputs: 124536     Socket messages sent: 0 Socket messages received: 0     Signals delivered: 0    Page size
#                                (bytes): 4096 Exit status: 0
#                       DEBUG    resource usage dict: {'time': 25.14, 'memory': 2025.52, 'cpu': 1.1}
#                       DEBUG    Add trajectory by wrapper type: linear
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    plot_trajectory
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [09/10/2025 04:29:48] DEBUG    add waypoints shape is (201, 500), finished!
#                       DEBUG    CondaBackend __init__
# [09/10/2025 04:29:49] DEBUG    Conda environment 'cfe' is available: Python 3.10.15
#                       INFO     method_backend: CondaBackend: function_name-cf_palantir, load_backend-cfe
#                       DEBUG    Temp wd: /tmp/tmpqku5k856
#                       INFO     cmd: conda run -n cfe --no-capture-output /usr/bin/time -v python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_palantir --adata_path=/tmp/tmpqku5k856/adata.h5ad --prior_information=/tmp/tmpqku5k856/prior_information.json
#                                --parameters=/tmp/tmpqku5k856/parameters.json --output_filename=/tmp/tmpqku5k856/output.pkl
# [09/10/2025 04:29:55] INFO     [stdout]repreprocess finish
# [09/10/2025 04:30:05] INFO     [stdout]Sampling and flocking waypoints...
#                       INFO     [stdout]Time for determining waypoints: 0.0005847851435343425 minutes
#                       INFO     [stdout]Determining pseudotime...
#                       INFO     [stdout]Shortest path distances using 30-nearest neighbor graph...
# [09/10/2025 04:30:17] INFO     [stdout]Time for shortest paths: 0.20530105034510296 minutes
#                       INFO     [stdout]Iteratively refining the pseudotime...
#                       INFO     [stdout]Correlation at iteration 1: 1.0000
#                       INFO     [stdout]Entropy and branch probabilities...
#                       INFO     [stdout]Markov chain construction...
#                       INFO     [stdout]Identification of terminal states...
#                       INFO     [stdout]Computing fundamental matrix and absorption probabilities...
# [09/10/2025 04:30:18] INFO     [stdout]Project results to all cells...
#                       INFO     [stdout]palantir execute finish
#                       INFO     [stdout]cf_palantir finish!
# [09/10/2025 04:30:21] DEBUG    [stderr]        Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py --function_name=cf_palantir
#                                --adata_path=/tmp/tmpqku5k856/adata.h5ad --prior_information=/tmp/tmpqku5k856/prior_information.json --parameters=/tmp/tmpqku5k856/parameters.json
#                                --output_filename=/tmp/tmpqku5k856/output.pkl"
#                       DEBUG    [stderr]        User time (seconds): 514.07
#                       DEBUG    [stderr]        System time (seconds): 30.51
#                       DEBUG    [stderr]        Percent of CPU this job got: 1824%
#                       DEBUG    [stderr]        Elapsed (wall clock) time (h:mm:ss or m:ss): 0:29.85
#                       DEBUG    [stderr]        Average shared text size (kbytes): 0
#                       DEBUG    [stderr]        Average unshared data size (kbytes): 0
#                       DEBUG    [stderr]        Average stack size (kbytes): 0
#                       DEBUG    [stderr]        Average total size (kbytes): 0
#                       DEBUG    [stderr]        Maximum resident set size (kbytes): 1152896
#                       DEBUG    [stderr]        Average resident set size (kbytes): 0
#                       DEBUG    [stderr]        Major (requiring I/O) page faults: 167
#                       DEBUG    [stderr]        Minor (reclaiming a frame) page faults: 5997737
#                       DEBUG    [stderr]        Voluntary context switches: 20707
#                       DEBUG    [stderr]        Involuntary context switches: 1320761
#                       DEBUG    [stderr]        Swaps: 0
#                       DEBUG    [stderr]        File system inputs: 0
#                       DEBUG    [stderr]        File system outputs: 416
#                       DEBUG    [stderr]        Socket messages sent: 0
#                       DEBUG    [stderr]        Socket messages received: 0
#                       DEBUG    [stderr]        Signals delivered: 0
#                       DEBUG    [stderr]        Page size (bytes): 4096
#                       DEBUG    [stderr]        Exit status: 0
#                       DEBUG    Conda finish
#                       DEBUG    resource usage string:  Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_palantir --adata_path=/tmp/tmpqku5k856/adata.h5ad --prior_information=/tmp/tmpqku5k856/prior_information.json
#                                --parameters=/tmp/tmpqku5k856/parameters.json --output_filename=/tmp/tmpqku5k856/output.pkl" User time (seconds): 514.07     System time (seconds): 30.51    Percent of
#                                CPU this job got: 1824%      Elapsed (wall clock) time (h:mm:ss or m:ss): 0:29.85    Average shared text size (kbytes): 0    Average unshared data size (kbytes): 0
#                                Average stack size (kbytes): 0  Average total size (kbytes): 0  Maximum resident set size (kbytes): 1152896     Average resident set size (kbytes): 0   Major (requiring
#                                I/O) page faults: 167  Minor (reclaiming a frame) page faults: 5997737 Voluntary context switches: 20707       Involuntary context switches: 1320761   Swaps: 0
#                                File system inputs: 0   File system outputs: 416        Socket messages sent: 0 Socket messages received: 0     Signals delivered: 0    Page size (bytes): 4096 Exit
#                                status: 0
#                       DEBUG    resource usage dict: {'time': 29.85, 'memory': 1125.88, 'cpu': 18.24}
#                       DEBUG    Add trajectory by wrapper type: linear
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    plot_trajectory
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
#                       DEBUG    add waypoints shape is (201, 500), finished!
#                       DEBUG    CondaBackend __init__
# [09/10/2025 04:30:23] DEBUG    Conda environment 'cfe' is available: Python 3.10.15
#                       INFO     method_backend: CondaBackend: function_name-cf_sctc, load_backend-cfe
#                       DEBUG    Temp wd: /tmp/tmpicvk4g99
#                       INFO     cmd: conda run -n cfe --no-capture-output /usr/bin/time -v python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=cf_sctc --adata_path=/tmp/tmpicvk4g99/adata.h5ad --prior_information=/tmp/tmpicvk4g99/prior_information.json
#                                --parameters=/tmp/tmpicvk4g99/parameters.json --output_filename=/tmp/tmpicvk4g99/output.pkl
# [09/10/2025 04:30:26] INFO     [stdout]cf_sctc finish!
# [09/10/2025 04:30:27] DEBUG    [stderr]        Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py --function_name=cf_sctc
#                                --adata_path=/tmp/tmpicvk4g99/adata.h5ad --prior_information=/tmp/tmpicvk4g99/prior_information.json --parameters=/tmp/tmpicvk4g99/parameters.json
#                                --output_filename=/tmp/tmpicvk4g99/output.pkl"
#                       DEBUG    [stderr]        User time (seconds): 3.58
#                       DEBUG    [stderr]        System time (seconds): 4.02
#                       DEBUG    [stderr]        Percent of CPU this job got: 394%
#                       DEBUG    [stderr]        Elapsed (wall clock) time (h:mm:ss or m:ss): 0:01.93
#                       DEBUG    [stderr]        Average shared text size (kbytes): 0
#                       DEBUG    [stderr]        Average unshared data size (kbytes): 0
#                       DEBUG    [stderr]        Average stack size (kbytes): 0
#                       DEBUG    [stderr]        Average total size (kbytes): 0
#                       DEBUG    [stderr]        Maximum resident set size (kbytes): 727524
#                       DEBUG    [stderr]        Average resident set size (kbytes): 0
#                       DEBUG    [stderr]        Major (requiring I/O) page faults: 0
#                       DEBUG    [stderr]        Minor (reclaiming a frame) page faults: 123174
#                       DEBUG    [stderr]        Voluntary context switches: 204
#                       DEBUG    [stderr]        Involuntary context switches: 1564526
#                       DEBUG    [stderr]        Swaps: 0
#                       DEBUG    [stderr]        File system inputs: 0
#                       DEBUG    [stderr]        File system outputs: 24
#                       DEBUG    [stderr]        Socket messages sent: 0
#                       DEBUG    [stderr]        Socket messages received: 0
#                       DEBUG    [stderr]        Signals delivered: 0
#                       DEBUG    [stderr]        Page size (bytes): 4096
#                       DEBUG    [stderr]        Exit status: 0
#                       DEBUG    Conda finish
#                       DEBUG    resource usage string:  Command being timed: "python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py --function_name=cf_sctc
#                                --adata_path=/tmp/tmpicvk4g99/adata.h5ad --prior_information=/tmp/tmpicvk4g99/prior_information.json --parameters=/tmp/tmpicvk4g99/parameters.json
#                                --output_filename=/tmp/tmpicvk4g99/output.pkl"     User time (seconds): 3.58       System time (seconds): 4.02     Percent of CPU this job got: 394%       Elapsed (wall
#                                clock) time (h:mm:ss or m:ss): 0:01.93    Average shared text size (kbytes): 0    Average unshared data size (kbytes): 0  Average stack size (kbytes): 0  Average total
#                                size (kbytes): 0  Maximum resident set size (kbytes): 727524      Average resident set size (kbytes): 0   Major (requiring I/O) page faults: 0    Minor (reclaiming a
#                                frame) page faults: 123174  Voluntary context switches: 204 Involuntary context switches: 1564526   Swaps: 0        File system inputs: 0   File system outputs: 24
#                                Socket messages sent: 0 Socket messages received: 0     Signals delivered: 0    Page size (bytes): 4096 Exit status: 0
#                       DEBUG    resource usage dict: {'time': 1.93, 'memory': 710.47, 'cpu': 3.94}
#                       DEBUG    Add trajectory by wrapper type: linear
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    plot_trajectory
# ...
#                       DEBUG    h52json script: /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_input_json2h5.R
# [09/10/2025 04:30:30] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_input_json2h5.R', '--input_json_filename',
#                                '/tmp/tmp81dgjbti/input.json', '--input_h5_filename', '/tmp/tmp81dgjbti/input.h5'], returncode=0, stdout='[1] "json2h5 successful!"\n', stderr='')
#                       DEBUG    json2h5 successful!
# [09/10/2025 04:31:01] DEBUG    Docker Finish
#                       DEBUG    h52json script: /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_output_h52json.R
# [09/10/2025 04:31:02] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_output_h52json.R', '--output_h5_filename',
#                                '/tmp/tmp81dgjbti/output.h5', '--output_json_filename', '/tmp/tmp81dgjbti/output.json'], returncode=0, stdout='[1] "h52json successful!"\n', stderr='')
#                       DEBUG    h52json successful!
#                       DEBUG    Save json successfully, path: /tmp/tmp81dgjbti/output.json
#                       DEBUG    resource usage dict: {'memory': 296.32, 'cpu': 0, 'time': 31.035490036010742}
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    plot_trajectory
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
# [09/10/2025 04:31:03] DEBUG    add waypoints shape is (201, 500), finished!
#                       INFO     backend:'conda' is not available for method:'ti_scorpius', choosing new backend: 'dynverse_docker'
#                       DEBUG    Docker image(dynverse/ti_scorpius:v2.0.0) loaded, entry point is '['/code/run.R']'
#                       INFO     method_backend: <cfe.method.fate_dynverse_docker_backend.DynverseDockerBackend object at 0x75bf335e4550>
#                       WARNING
#                                                Prior information dimred is optional, but missing from dataset 20250910_162913__FateAnnData__0cMfcS83aT.
#
#                                                Will not give this prior to method.
#
#                       DEBUG    Temp wd: /tmp/tmphdf3lib3
#                       DEBUG    expression transfer to csc from csr
# [09/10/2025 04:31:04] DEBUG    Save json successfully, path: /tmp/tmphdf3lib3/input.json
#                       DEBUG    h52json script: /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_input_json2h5.R
# [09/10/2025 04:31:06] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_input_json2h5.R', '--input_json_filename',
#                                '/tmp/tmphdf3lib3/input.json', '--input_h5_filename', '/tmp/tmphdf3lib3/input.h5'], returncode=0, stdout='[1] "json2h5 successful!"\n', stderr='')
#                       DEBUG    json2h5 successful!
# [09/10/2025 04:31:08] DEBUG    Docker Finish
#                       DEBUG    h52json script: /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_output_h52json.R
# [09/10/2025 04:31:09] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_output_h52json.R', '--output_h5_filename',
#                                '/tmp/tmphdf3lib3/output.h5', '--output_json_filename', '/tmp/tmphdf3lib3/output.json'], returncode=0, stdout='[1] "h52json successful!"\n', stderr='')
#                       DEBUG    h52json successful!
#                       DEBUG    Save json successfully, path: /tmp/tmphdf3lib3/output.json
#                       DEBUG    resource usage dict: {'memory': 352.44, 'cpu': 0, 'time': 2.7271523475646973}
#                       DEBUG    FateAnnData add_trajectory
# [09/10/2025 04:31:10] DEBUG    plot_trajectory
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
#                       DEBUG    add waypoints shape is (201, 500), finished!
#                       INFO     backend:'conda' is not available for method:'ti_embeddr', choosing new backend: 'dynverse_docker'
#                       DEBUG    Docker image(dynverse/ti_embeddr:v0.9.9.01) loaded, entry point is '['/code/run.R']'
#                       INFO     method_backend: <cfe.method.fate_dynverse_docker_backend.DynverseDockerBackend object at 0x75bf337cc130>
#                       DEBUG    Temp wd: /tmp/tmpwf8tbfuo
#                       DEBUG    expression transfer to csc from csr
# [09/10/2025 04:31:11] DEBUG    Save json successfully, path: /tmp/tmpwf8tbfuo/input.json
#                       DEBUG    h52json script: /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_input_json2h5.R
# [09/10/2025 04:31:13] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_input_json2h5.R', '--input_json_filename',
#                                '/tmp/tmpwf8tbfuo/input.json', '--input_h5_filename', '/tmp/tmpwf8tbfuo/input.h5'], returncode=0, stdout='[1] "json2h5 successful!"\n', stderr='')
#                       DEBUG    json2h5 successful!
# [09/10/2025 04:31:15] INFO     [Docker] Welcome to Bioconductor
#                       INFO     [Docker]
#                       INFO     [Docker] Vignettes contain introductory material; view with
#                       INFO     [Docker] 'browseVignettes()'. To cite Bioconductor, see
#                       INFO     [Docker] 'citation("Biobase")', and for packages 'citation("pkgname")'.
#                       INFO     [Docker]
#                       INFO     [Docker] Loading required package: ggplot2
# [09/10/2025 04:31:16] INFO     [Docker] Warning messages:
#                       INFO     [Docker] 1: In scaterlegacy::newSCESet(exprsData = t(expression)) :
#                       INFO     [Docker] 'logExprsOffset' should be set manually for non-count data
#                       INFO     [Docker] 2: In scaterlegacy::newSCESet(exprsData = t(expression)) :
#                       INFO     [Docker] 'lowerDetectionLimit' should be set manually for log-expression values
# [09/10/2025 04:31:20] INFO     [Docker] Warning message:
#                       INFO     [Docker] In laplacian_eigenmap(W, measure_type = measure_type, p = p) :
#                       INFO     [Docker] More than one non-zero eigenvalue - disjoint clusters.
# [09/10/2025 04:31:21] DEBUG    Docker Finish
#                       DEBUG    h52json script: /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_output_h52json.R
# [09/10/2025 04:31:22] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/../rscript/docker_output_h52json.R', '--output_h5_filename',
#                                '/tmp/tmpwf8tbfuo/output.h5', '--output_json_filename', '/tmp/tmpwf8tbfuo/output.json'], returncode=0, stdout='[1] "h52json successful!"\n', stderr='')
#                       DEBUG    h52json successful!
#                       DEBUG    Save json successfully, path: /tmp/tmpwf8tbfuo/output.json
#                       DEBUG    resource usage dict: {'memory': 841.95, 'cpu': 0, 'time': 7.856992721557617}
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    plot_trajectory
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
#                       DEBUG    add waypoints shape is (201, 500), finished!

# %%
color_list = []
for method_name in method2parameters.keys():
    color_list.append(f"{method_name}_pseudotime")
    
sc.pl.umap(fadata, color=color_list)

# %% [markdown]
# Show model name

# %%
parsed_model_name_list = fadata.get_all_model_name() # 解析后的模型名称
model_name_list = fadata.get_all_model_name(parse=False)
parsed_model_name_list, model_name_list
# Out:
# [09/10/2025 04:31:24] WARNING  'ref' is not a valid random_time_string, don't need parse
# (['ref',
#   'comp1-conda',
#   'cytotrace2-conda',
#   'palantir-conda',
#   'sctc-conda',
#   'ti_comp1-dynverse_docker',
#   'ti_scorpius-dynverse_docker',
#   'ti_embeddr-dynverse_docker'],
#  ['ref',
#   '20250910_162915__comp1-conda__uv6yphqhsl',
#   '20250910_162920__cytotrace2-conda__Z3jttD4cyw',
#   '20250910_162949__palantir-conda__DtB73zre1n',
#   '20250910_163023__sctc-conda__tIZwkskDig',
#   '20250910_163028__ti_comp1-dynverse_docker__KboXfTOQZT',
#   '20250910_163103__ti_scorpius-dynverse_docker__H5ORvAx5lh',
#   '20250910_163110__ti_embeddr-dynverse_docker__3I2wdDjvmI'])

# %% [markdown]
# ## 4. Metric

# %%
# available metrics:
# cfe.metric.metrics

# metrics are chosen to be calculate
implemented = [
    # "edge_flip",
    "him",
    # "F1_branches",
    # "F1_milestones"
    # "correlation",
    # "rf_mse",
    # "rf_rsq",
    # "rf_nmse",
    # "lm_mse",
    # "lm_rsq",
    # "lm_nmse",
    # feature importance need to be fixed
    # "featureimp_cor", 
    # "featureimp_wcor",
    # "featureimp_ks",
    # "featureimp_wilcox",
    
]
# =========================================================================================================

# metric calculation
# extract all model names
models = fadata.trajectory_history_dict.keys()
models
fadata.update_uns_cfe() # update fadata.uns["cfe"]

# ensure waypoint wrapper for every model
for m in set(models) | {"ref"}:
    fadata.model_name = m
    if not fadata.is_wrapped_with_waypoints:
        fadata.add_waypoints()
        
# metric calculation and collect results
records = {}
for model in models:
    record = fadata.get_resource_usage(model) # extract resource usage
    if not (("angle" in model) or ("ref" in model)):
        # skip ref itself, skip ref angle (node loop may result in error)
        print(f"Calculating metrics for model: {model}")
        # metric calculation
        metric = cfe.metric.calculate_metrics(
            fadata,
            now_model=model,
            ref_model="ref",
            simplify=False, 
            metrics=implemented
        )
        # NOTE: add new psudotime correlation metric
        psudotime_corr = cfe.metric.calculate_pseudotime_correlation(
            fadata=fadata,
            # start_cell=start_cell,
            ref_start_milestone="Ductal",
            pred_start_milestone="milestone_begin",
            ref_model="ref",
            pred_model=model,
        )
        metric["psudotime_corr"] = psudotime_corr
        record.update(metric)
    records[model] = record
    

# metric dataframe
df = pd.DataFrame(records).T
styled_df = cfe.plot.style_benchmark(df)
df.to_csv("tmp/benchmark.csv")
styled_df
# Out:
# Calculating metrics for model: 20250910_162915__comp1-conda__uv6yphqhsl
#                       DEBUG    find key:'pseudotime_from_Ductal' in trajectory dict, use it directly
#                       DEBUG    calculating new pseudotime
#                       DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_milestone_begin`
# Calculating metrics for model: 20250910_162920__cytotrace2-conda__Z3jttD4cyw
#                       DEBUG    find key:'pseudotime_from_Ductal' in trajectory dict, use it directly
#                       DEBUG    calculating new pseudotime
#                       DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_milestone_begin`
# Calculating metrics for model: 20250910_162949__palantir-conda__DtB73zre1n
#                       DEBUG    find key:'pseudotime_from_Ductal' in trajectory dict, use it directly
#                       DEBUG    calculating new pseudotime
#                       DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_milestone_begin`
# Calculating metrics for model: 20250910_163023__sctc-conda__tIZwkskDig
#                       DEBUG    find key:'pseudotime_from_Ductal' in trajectory dict, use it directly
#                       DEBUG    calculating new pseudotime
#                       DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_milestone_begin`
# Calculating metrics for model: 20250910_163028__ti_comp1-dynverse_docker__KboXfTOQZT
#                       DEBUG    find key:'pseudotime_from_Ductal' in trajectory dict, use it directly
#                       DEBUG    calculating new pseudotime
#                       DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_milestone_begin`
# Calculating metrics for model: 20250910_163103__ti_scorpius-dynverse_docker__H5ORvAx5lh
#                       DEBUG    find key:'pseudotime_from_Ductal' in trajectory dict, use it directly
#                       DEBUG    calculating new pseudotime
#                       DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_milestone_begin`
# Calculating metrics for model: 20250910_163110__ti_embeddr-dynverse_docker__3I2wdDjvmI
#                       DEBUG    find key:'pseudotime_from_Ductal' in trajectory dict, use it directly
#                       DEBUG    calculating new pseudotime
# [09/10/2025 04:31:25] DEBUG    save pseudotime to trajectory dict with key: `pseudotime_from_milestone_begin`
# <style type="text/css">
# #T_9bc59_row0_col0, #T_9bc59_row0_col1, #T_9bc59_row0_col2, #T_9bc59_row0_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9bc59_row0_col3, #T_9bc59_row1_col3, #T_9bc59_row2_col1, #T_9bc59_row2_col3, #T_9bc59_row3_col2, #T_9bc59_row3_col3, #T_9bc59_row4_col3, #T_9bc59_row5_col0, #T_9bc59_row5_col3, #T_9bc59_row6_col3, #T_9bc59_row6_col4, #T_9bc59_row7_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9bc59_row1_col0, #T_9bc59_row3_col4, #T_9bc59_row5_col1, #T_9bc59_row5_col2, #T_9bc59_row6_col2, #T_9bc59_row7_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_9bc59_row1_col1 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_9bc59_row1_col2 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_9bc59_row1_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_9bc59_row2_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_9bc59_row2_col2 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_9bc59_row2_col4 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_9bc59_row3_col0 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_9bc59_row3_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_9bc59_row4_col0 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_9bc59_row4_col1 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_9bc59_row4_col2 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_9bc59_row4_col4 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_9bc59_row5_col4 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_9bc59_row6_col0 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_9bc59_row6_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_9bc59_row7_col0 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_9bc59_row7_col1 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_9bc59_row7_col4 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9bc59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bc59_level0_col0" class="col_heading level0 col0" >time</th>
#       <th id="T_9bc59_level0_col1" class="col_heading level0 col1" >memory</th>
#       <th id="T_9bc59_level0_col2" class="col_heading level0 col2" >cpu</th>
#       <th id="T_9bc59_level0_col3" class="col_heading level0 col3" >him</th>
#       <th id="T_9bc59_level0_col4" class="col_heading level0 col4" >psudotime_corr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bc59_level0_row0" class="row_heading level0 row0" >ref</th>
#       <td id="T_9bc59_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_9bc59_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_9bc59_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_9bc59_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_9bc59_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9bc59_level0_row1" class="row_heading level0 row1" >20250910_162915__comp1-conda__uv6yphqhsl</th>
#       <td id="T_9bc59_row1_col0" class="data row1 col0" >1.5300</td>
#       <td id="T_9bc59_row1_col1" class="data row1 col1" >649.0400</td>
#       <td id="T_9bc59_row1_col2" class="data row1 col2" >3.3400</td>
#       <td id="T_9bc59_row1_col3" class="data row1 col3" >0.2500</td>
#       <td id="T_9bc59_row1_col4" class="data row1 col4" >0.8709</td>
#     </tr>
#     <tr>
#       <th id="T_9bc59_level0_row2" class="row_heading level0 row2" >20250910_162920__cytotrace2-conda__Z3jttD4cyw</th>
#       <td id="T_9bc59_row2_col0" class="data row2 col0" >25.1400</td>
#       <td id="T_9bc59_row2_col1" class="data row2 col1" >2025.5200</td>
#       <td id="T_9bc59_row2_col2" class="data row2 col2" >1.1000</td>
#       <td id="T_9bc59_row2_col3" class="data row2 col3" >0.2500</td>
#       <td id="T_9bc59_row2_col4" class="data row2 col4" >0.8229</td>
#     </tr>
#     <tr>
#       <th id="T_9bc59_level0_row3" class="row_heading level0 row3" >20250910_162949__palantir-conda__DtB73zre1n</th>
#       <td id="T_9bc59_row3_col0" class="data row3 col0" >29.8500</td>
#       <td id="T_9bc59_row3_col1" class="data row3 col1" >1125.8800</td>
#       <td id="T_9bc59_row3_col2" class="data row3 col2" >18.2400</td>
#       <td id="T_9bc59_row3_col3" class="data row3 col3" >0.2500</td>
#       <td id="T_9bc59_row3_col4" class="data row3 col4" >0.9577</td>
#     </tr>
#     <tr>
#       <th id="T_9bc59_level0_row4" class="row_heading level0 row4" >20250910_163023__sctc-conda__tIZwkskDig</th>
#       <td id="T_9bc59_row4_col0" class="data row4 col0" >1.9300</td>
#       <td id="T_9bc59_row4_col1" class="data row4 col1" >710.4700</td>
#       <td id="T_9bc59_row4_col2" class="data row4 col2" >3.9400</td>
#       <td id="T_9bc59_row4_col3" class="data row4 col3" >0.2500</td>
#       <td id="T_9bc59_row4_col4" class="data row4 col4" >-0.9590</td>
#     </tr>
#     <tr>
#       <th id="T_9bc59_level0_row5" class="row_heading level0 row5" >20250910_163028__ti_comp1-dynverse_docker__KboXfTOQZT</th>
#       <td id="T_9bc59_row5_col0" class="data row5 col0" >31.0355</td>
#       <td id="T_9bc59_row5_col1" class="data row5 col1" >296.3200</td>
#       <td id="T_9bc59_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_9bc59_row5_col3" class="data row5 col3" >0.2500</td>
#       <td id="T_9bc59_row5_col4" class="data row5 col4" >-0.9433</td>
#     </tr>
#     <tr>
#       <th id="T_9bc59_level0_row6" class="row_heading level0 row6" >20250910_163103__ti_scorpius-dynverse_docker__H5ORvAx5lh</th>
#       <td id="T_9bc59_row6_col0" class="data row6 col0" >2.7272</td>
#       <td id="T_9bc59_row6_col1" class="data row6 col1" >352.4400</td>
#       <td id="T_9bc59_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_9bc59_row6_col3" class="data row6 col3" >0.2500</td>
#       <td id="T_9bc59_row6_col4" class="data row6 col4" >-0.9753</td>
#     </tr>
#     <tr>
#       <th id="T_9bc59_level0_row7" class="row_heading level0 row7" >20250910_163110__ti_embeddr-dynverse_docker__3I2wdDjvmI</th>
#       <td id="T_9bc59_row7_col0" class="data row7 col0" >7.8570</td>
#       <td id="T_9bc59_row7_col1" class="data row7 col1" >841.9500</td>
#       <td id="T_9bc59_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_9bc59_row7_col3" class="data row7 col3" >0.2500</td>
#       <td id="T_9bc59_row7_col4" class="data row7 col4" >-0.9475</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 现有指标计算问题：
#
# （1）计算太慢了（首要问题）
#
# （2）大部分指标计算为空，feature相关指标报错
