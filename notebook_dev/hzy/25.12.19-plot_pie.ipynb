# %%
import cafe
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3

# %% [markdown]
# cluster wrapper

# %%
model_name = "stavia"
fadata = cafe.data.read_pancrease()
fadata.load_trajectory_dict(model_name_list=[model_name]) # load all trajectories
cafe.plot.plot_pie(fadata, model_name=model_name, node_size_scale=3.0)
fadata
# Out:
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score', 'raw_index'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca', 'id', 'cafe', 'filename'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced', 'expression', 'counts'
#     obsp: 'distances', 'connectivities'

# %%
cafe.plot.plot_pie(fadata, model_name="ref", node_size_scale=3.0)
fadata
# Out:
# WARNING  |- the wrapper type is not cluster, try to group cells onto the nearest milestone
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score', 'raw_index'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca', 'id', 'cafe', 'filename'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced', 'expression', 'counts'
#     obsp: 'distances', 'connectivities'
