# %%
import cfe
# Out:
# INFO
#             _____     _ _ ______    _       ______            _
#            / ____|   | | |  ____|  | |     |  ____|          | |
#           | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#           | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#           | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#            \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                        | |
#                                                        |_|
#
# INFO      Version: 0.1.2_alpha

# %% [markdown]
# data

# %%
fadata = cfe.data.read_pancrease()
cfe.plot.plot_trajectory(fadata, curve=False) # 后续再可视化
fadata
# Out:
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score', 'raw_index'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca', 'id', 'cfe', 'filename'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced', 'expression', 'counts'
#     obsp: 'distances', 'connectivities'

# %% [markdown]
# direct(ref轨迹直接用ref)

# %%
cfe.plot.plot_wrapper(fadata, wrapper_type="direct", mode="graph")
cfe.plot.plot_wrapper(fadata, wrapper_type="direct", mode="trajectory")

# %% [markdown]
# linear(Comp1, Cytotrace2)

# %%
# # 使用ref
# cfe.plot.plot_pseudotime_embedding(fadata)
# cfe.plot.plot_pseudotime_stack(fadata)

# 读取comp1方法结果
model_name = "comp1"
fadata.model_name = model_name
fadata.load_trajectory_dict(model_name_list=[model_name])

mode_list = ["embedding", "stack"]
for mode in mode_list:
    cfe.plot.plot_wrapper(fadata, mode=mode)
# Out:
# INFO     |- find wrapper type: linear
# INFO     |- find wrapper type: linear

# %% [markdown]
# probability (StateComp, CellRank)

# %%
# 读取state_comp结果
model_name = "state_comp"
fadata.model_name = model_name
fadata.load_trajectory_dict(model_name_list=[model_name])

mode_list = ["embedding", "star"]
for mode in mode_list:
    cfe.plot.plot_wrapper(fadata, mode=mode)
# Out:
# INFO     |- find wrapper type: probability
# INFO     |- find wrapper type: probability

# %% [markdown]
# Cycle()

# %% [markdown]
# cluster(Cluster MST, StaVia)

# %%
# 读取ClusterMST结果
model_name = "cluster_mst"
fadata.model_name = model_name
fadata.load_trajectory_dict(model_name_list=[model_name])

cfe.plot.plot_wrapper(fadata, model_name=model_name)
# Out:
# INFO     |- find wrapper type: cluster
# INFO     |- No mode specified, using default for 'cluster': 'embedding'

# %% [markdown]
# projection(Projection MST)

# %%
# 读取Projection MST结果
model_name = "projection_mst"
fadata.model_name = model_name
fadata.load_trajectory_dict(model_name_list=[model_name])

#  TODO: 有点不像是垂直投影, 需要解释
cfe.plot.plot_wrapper(fadata, model_name=model_name)
# Out:
# INFO     |- find wrapper type: projection
# INFO     |- No mode specified, using default for 'projection': 'embedding'

# %% [markdown]
# graph(Graph MST)

# %%
# 读取Projection MST结果（有点不像是垂直投影）
model_name = "graph_mst"
fadata.model_name = model_name
fadata.load_trajectory_dict(model_name_list=[model_name])

cfe.plot.plot_wrapper(fadata, model_name=model_name) # TOOD: 当前简化效果不明显，绘制结果也不明显
# Out:
# INFO     |- find wrapper type: graph
# INFO     |- No mode specified, using default for 'graph': 'embedding'

# %% [markdown]
# velocity

# %%
# 读取state_comp结果
model_name = "scvelo"
fadata.model_name = model_name
fadata.load_trajectory_dict(model_name_list=[model_name])

mode_list = ["stream", "grid", "embedding"]
for mode in mode_list:
    cfe.plot.plot_wrapper(fadata, mode=mode)
# Out:
# INFO     |- find wrapper type: velocity
# INFO     |- find wrapper type: velocity
# INFO     |- find wrapper type: velocity
