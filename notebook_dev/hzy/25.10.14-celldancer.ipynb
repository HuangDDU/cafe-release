# %%
import cafe

cafe.logger.setLevel("DEBUG")

# cafe.settings.backend = "cfe_docker"
cafe.settings.backend = "conda"
# Out:
# [10/14/2025 05:24:06] INFO
#                                   _____     _ _ ______    _       ______            _
#                                  / ____|   | | |  ____|  | |     |  ____|          | |
#                                 | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                 | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                 | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                  \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                              | |
#                                                                              |_|

# %%
fadata = cafe.data.read_pancrease()

fadata = cafe.data.read_h5ad("../../tests/data/pancrease_scvelo_500_fadata.h5ad")
fadata.add_prior_information(start_cell="cell_000")

fadata
# Out:
# [10/14/2025 05:24:07] DEBUG    transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    add prior information 'start_cell': 'cell_1103'
#                       DEBUG    FateAnnData add_trajectory
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    parse 'MilestoneWrapper' object for ref
# AnnData object with n_obs × n_vars = 500 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     uns: 'cfe'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'count', 'expression', 'spliced', 'unspliced'

# %%
parameters = {
    "repreprocess": True,
    # "repreprocess_kwargs": {"n_top_genes": 100}
}
method = cafe.method.FateMethod(method_name="celldancer")
method.infer_trajectory(fadata, parameters)
# Out:
#                       DEBUG    CondaBackend __init__
# [10/14/2025 05:24:09] DEBUG    Conda environment 'celldancer' is available: Python 3.7.16
#                       DEBUG    Loaded function 'celldancer': <function celldancer at 0x7e4822314d30>
#                       INFO     method backend loaded: CondaBackend: celldancer in conda env 'celldancer'
#                       DEBUG    merged parameters: {'repreprocess': True}
#                       DEBUG    Temp wd: /tmp/tmp0i7huh2n
#                       INFO     cmd: conda run -n celldancer --no-capture-output python /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/cfe/method/function/parse_args.py
#                                --function_name=celldancer --adata_path=/tmp/tmp0i7huh2n/adata.h5ad --parameters=/tmp/tmp0i7huh2n/parameters.json --output_filename=/tmp/tmp0i7huh2n/output.pkl
# [10/14/2025 05:24:13] INFO     [stdout]Filtered out 24737 genes that are detected 20 counts (shared).
#                       INFO     [stdout]Normalized count data: X, spliced, unspliced.
#                       INFO     [stdout]Extracted 2000 highly variable genes.
#                       INFO     [stdout]Logarithmized X.
#                       INFO     [stdout]computing neighbors
# [10/14/2025 05:24:16] INFO     [stdout]    finished (0:00:02) --> added
#                       INFO     [stdout]    'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
#                       INFO     [stdout]computing moments based on connectivities
#                       INFO     [stdout]    finished (0:00:00) --> added
#                       DEBUG    [stderr]
#                       INFO     [stdout]    'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#                       DEBUG    [stderr]  0%|          | 0/2000 [00:00<?, ?it/s]
#                       DEBUG    [stderr]  1%|▏         | 29/2000 [00:00<00:06, 283.41it/s]
#                       DEBUG    [stderr]  3%|▎         | 60/2000 [00:00<00:06, 296.11it/s]
#                       DEBUG    [stderr]  5%|▍         | 91/2000 [00:00<00:06, 300.50it/s]
#                       DEBUG    [stderr]  6%|▌         | 122/2000 [00:00<00:06, 299.11it/s]
#                       DEBUG    [stderr]  8%|▊         | 153/2000 [00:00<00:06, 301.97it/s]
# [10/14/2025 05:24:17] DEBUG    [stderr]  9%|▉         | 184/2000 [00:00<00:06, 301.01it/s]
#                       DEBUG    [stderr] 11%|█         | 215/2000 [00:00<00:05, 302.18it/s]
#                       DEBUG    [stderr] 12%|█▏        | 246/2000 [00:00<00:05, 302.97it/s]
#                       DEBUG    [stderr] 14%|█▍        | 277/2000 [00:00<00:05, 301.01it/s]
#                       DEBUG    [stderr] 15%|█▌        | 308/2000 [00:01<00:05, 298.17it/s]
#                       DEBUG    [stderr] 17%|█▋        | 339/2000 [00:01<00:05, 299.85it/s]
#                       DEBUG    [stderr] 18%|█▊        | 370/2000 [00:01<00:05, 301.26it/s]
#                       DEBUG    [stderr] 20%|██        | 401/2000 [00:01<00:05, 301.71it/s]
#                       DEBUG    [stderr] 22%|██▏       | 432/2000 [00:01<00:05, 285.14it/s]
# [10/14/2025 05:24:18] DEBUG    [stderr] 23%|██▎       | 463/2000 [00:01<00:05, 291.19it/s]
#                       DEBUG    [stderr] 25%|██▍       | 493/2000 [00:01<00:05, 292.32it/s]
#                       DEBUG    [stderr] 26%|██▌       | 523/2000 [00:01<00:05, 292.57it/s]
#                       DEBUG    [stderr] 28%|██▊       | 553/2000 [00:01<00:04, 293.64it/s]
#                       DEBUG    [stderr] 29%|██▉       | 584/2000 [00:01<00:04, 295.93it/s]
#                       DEBUG    [stderr] 31%|███       | 614/2000 [00:02<00:04, 290.41it/s]
#                       DEBUG    [stderr] 32%|███▏      | 645/2000 [00:02<00:04, 293.98it/s]
#                       DEBUG    [stderr] 34%|███▍      | 676/2000 [00:02<00:04, 296.68it/s]
#                       DEBUG    [stderr] 35%|███▌      | 706/2000 [00:02<00:04, 297.48it/s]
#                       DEBUG    [stderr] 37%|███▋      | 737/2000 [00:02<00:04, 299.30it/s]
# [10/14/2025 05:24:19] DEBUG    [stderr] 38%|███▊      | 768/2000 [00:02<00:04, 299.70it/s]
#                       DEBUG    [stderr] 40%|███▉      | 798/2000 [00:02<00:04, 299.51it/s]
#                       DEBUG    [stderr] 41%|████▏     | 828/2000 [00:02<00:03, 299.29it/s]
#                       DEBUG    [stderr] 43%|████▎     | 859/2000 [00:02<00:03, 299.78it/s]
#                       DEBUG    [stderr] 44%|████▍     | 889/2000 [00:02<00:03, 296.52it/s]
#                       DEBUG    [stderr] 46%|████▌     | 919/2000 [00:03<00:03, 293.87it/s]
#                       DEBUG    [stderr] 97%|█████████▋| 1932/2000 [00:06<00:00, 300.06it/s]
# [10/14/2025 05:24:23] DEBUG    [stderr] 98%|█████████▊| 1963/2000 [00:06<00:00, 300.65it/s]
#                       DEBUG    [stderr]100%|█████████▉| 1994/2000 [00:06<00:00, 300.88it/s]
#                       DEBUG    [stderr]100%|██████████| 2000/2000 [00:06<00:00, 297.68it/s]
# [10/14/2025 05:24:25] INFO     [stdout]Using /home/huang/PyCode/scRNA/CellFateExplorer/CellFateExplorer/notebook_dev/hzy/cellDancer_velocity_2025-10-14 17-24-25 as the output path.
# [10/14/2025 05:24:31] INFO     [stdout]Arranging genes for parallel job.
#                       INFO     [stdout]2000  genes were arranged to  84  portions.
#                       DEBUG    [stderr]
#                       DEBUG    [stderr]
# [10/14/2025 05:24:42] DEBUG    [stderr]Velocity Estimation:   0%|          | 0/84 [00:00<?, ?it/s][A
#                       DEBUG    [stderr]
# [10/14/2025 05:24:44] DEBUG    [stderr]Velocity Estimation:   1%|          | 1/84 [00:11<15:24, 11.14s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:24:47] DEBUG    [stderr]Velocity Estimation:   2%|▏         | 2/84 [00:13<08:02,  5.89s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:24:49] DEBUG    [stderr]Velocity Estimation:   4%|▎         | 3/84 [00:15<05:51,  4.34s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:24:52] DEBUG    [stderr]Velocity Estimation:   5%|▍         | 4/84 [00:18<04:56,  3.71s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:24:55] DEBUG    [stderr]Velocity Estimation:   6%|▌         | 5/84 [00:21<04:24,  3.35s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:24:58] DEBUG    [stderr]Velocity Estimation:   7%|▋         | 6/84 [00:24<04:14,  3.27s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:00] DEBUG    [stderr]Velocity Estimation:   8%|▊         | 7/84 [00:26<03:53,  3.03s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:03] DEBUG    [stderr]Velocity Estimation:  10%|▉         | 8/84 [00:29<03:39,  2.89s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:06] DEBUG    [stderr]Velocity Estimation:  11%|█         | 9/84 [00:32<03:29,  2.80s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:08] DEBUG    [stderr]Velocity Estimation:  12%|█▏        | 10/84 [00:34<03:20,  2.71s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:11] DEBUG    [stderr]Velocity Estimation:  13%|█▎        | 11/84 [00:37<03:11,  2.62s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:13] DEBUG    [stderr]Velocity Estimation:  14%|█▍        | 12/84 [00:39<03:10,  2.65s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:16] DEBUG    [stderr]Velocity Estimation:  15%|█▌        | 13/84 [00:42<03:01,  2.56s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:18] DEBUG    [stderr]Velocity Estimation:  17%|█▋        | 14/84 [00:44<02:59,  2.57s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:21] DEBUG    [stderr]Velocity Estimation:  18%|█▊        | 15/84 [00:47<02:57,  2.57s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:23] DEBUG    [stderr]Velocity Estimation:  19%|█▉        | 16/84 [00:49<02:54,  2.57s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:26] DEBUG    [stderr]Velocity Estimation:  20%|██        | 17/84 [00:52<02:45,  2.47s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:28] DEBUG    [stderr]Velocity Estimation:  21%|██▏       | 18/84 [00:54<02:47,  2.54s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:31] DEBUG    [stderr]Velocity Estimation:  23%|██▎       | 19/84 [00:57<02:45,  2.55s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25:33] DEBUG    [stderr]Velocity Estimation:  24%|██▍       | 20/84 [00:59<02:40,  2.51s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:25
/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:28:07] DEBUG    [stderr]Velocity Estimation:  96%|█████████▋| 81/84 [03:34<00:07,  2.34s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:28:10] DEBUG    [stderr]Velocity Estimation:  98%|█████████▊| 82/84 [03:36<00:04,  2.37s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:28:11] DEBUG    [stderr]Velocity Estimation:  99%|█████████▉| 83/84 [03:38<00:02,  2.35s/it][A
#                       DEBUG    [stderr]
#                       DEBUG    [stderr]Velocity Estimation: 100%|██████████| 84/84 [03:39<00:00,  1.96s/it][A
#                       DEBUG    [stderr]
# [10/14/2025 05:28:18] INFO     [stdout]celldancer finish!
# [10/14/2025 05:28:20] DEBUG    [stderr]                                                                    [A
#                       DEBUG    Conda finish
#                       DEBUG    Add trajectory by wrapper type: velocity
#                       DEBUG    Create a FateAnnData object from an existing AnnData object.
#                       DEBUG    recognize 'clusters' in '.obs' columns as 'cluster' key
#                       DEBUG    recognize 'X_umap' in '.obsm' keys as 'basis' key
#                       DEBUG    filterd adata: AnnData object with n_obs × n_vars = 500 × 2000
#                                    obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#                                    uns: 'cfe'
#                                    obsm: 'X_pca', 'X_umap'
#                                    layers: 'count', 'expression', 'spliced', 'unspliced'
#                       DEBUG    use given velocity embedding, use strategy 'low_dim_paga' to get milestone_network
# WARNING: The neighbor graph has an unexpected format (e.g. computed outside scvelo)
# or is corrupted (e.g. due to subsetting). Consider recomputing with `pp.neighbors`.
# computing neighbors
#     finished (0:00:03) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 1/24 cores)
#   0%|          | 0/500 [00:00<?, ?cells/s]
#     finished (0:00:00) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)
# computing terminal states
#     identified 2 regions of root cells and 0 region of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# running PAGA using priors: ['velocity_pseudotime']
#     finished (0:00:00) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)
# [10/14/2025 05:28:24] DEBUG    milestone_network:             from             to  length  directed
#                                8          Ductal    Ngn3 low EP       1      True
#                                17    Ngn3 low EP   Ngn3 high EP       1      True
#                                26   Ngn3 high EP  Pre-endocrine       1      True
#                                35  Pre-endocrine           Beta       1      True
#                                44           Beta          Alpha       1      True
#                                51  Pre-endocrine          Delta       1      True
#                       INFO     discrete milestones: ['Epsilon']
#                       DEBUG    FateAnnData add_trajectory
#                       INFO     method infer trajectory successfully: CondaBackend: celldancer in conda env 'celldancer'

# %%
# fix for isolated milestones and cells.
cafe.plot.plot_trajectory(fadata, color="clusters")
# Out:
#                       DEBUG    extract 'X_umap' from prior infomation as parameter 'basis'
#                       DEBUG    plot_trajectory
#                       DEBUG    calculate new trajectory embedding for model_name:None, basis:X_umap.
#                       DEBUG    add waypoints
#                       DEBUG    FateAnnData add_waypoints
#                       DEBUG    add waypoints shape is (211, 500) for 'None', finished!
# <Axes: title={'center': 'clusters'}, xlabel='X_umap1', ylabel='X_umap2'>

# %%
# TODO Velocity Wrapper UMAP优化
