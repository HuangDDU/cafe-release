# %%
import cafe

cafe.logger.setLevel("DEBUG")
cafe.__file__
# Out:
# INFO
#              ██████╗ █████╗ ███████╗███████╗
#            ██╔════╝██╔══██╗██╔════╝██╔════╝
#            ██║     ███████║█████╗  █████╗
#            ██║     ██╔══██║██╔══╝  ██╔══╝
#            ╚██████╗██║  ██║██║     ███████╗
#              ╚═════╝╚═╝  ╚═╝╚═╝     ╚══════╝
#
# INFO      Version: 0.1.3
# '/root/PyCode/scRNA/CellFateExplorer/cafe-release/cafe/__init__.py'

# %%
model_name = "stavia_problem"
fadata = cafe.data.read_pancrease()
fadata.load_trajectory_dict(model_name_list=[model_name])
fadata
# Out:
# DEBUG    |- Reading data from '/root/PyCode/scRNA/data/Pancreas/endocrinogenesis_day15.h5ad'...
# DEBUG    |- transfer 'X' and 'Spliced' matrix from csr to csc for better dynverse docker performance
# DEBUG    |- Create a FateAnnData object from an existing AnnData object.
# DEBUG    |- recognizing prior information...
# DEBUG    |--- recognize 'clusters' in '.obs' columns as 'cluster' key
# DEBUG    |--- recognize 'X_umap' in '.obsm' keys as 'basis' key
# DEBUG    |- add prior information...
# DEBUG    |--- add 'start_cell': 'cell_1103'
# DEBUG    |- FateAnnData add_trajectory
# DEBUG    |- synchronize milestone color with reference color dict.
# DEBUG    |- 'ref' is not a valid random_time_string, don't need parse
# DEBUG    |- model 'stavia_problem' not found in trajectory_history_dict
# DEBUG    |- load trajectory 'stavia_problem' from '.cafe/pancreas/trajectory_history/stavia_problem.pkl'
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score', 'raw_index'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca', 'id', 'cafe', 'filename'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced', 'expression', 'counts'
#     obsp: 'distances', 'connectivities'

# %%
cafe.plot.plot_trajectory(fadata, model_name=model_name)
# cafe.plot.plot_wrapper(fadata, model_name=model_name, wrapper_type="velocity")
fadata
# Out:
# DEBUG    |- extract 'clusters' from prior infomation as parameter 'color'
# DEBUG    |- extract 'X_umap' from prior infomation as parameter 'basis'
# DEBUG    |- plot_trajectory for model_name:'stavia_problem', color:'clusters'
# DEBUG    |- 'stavia_problem' is not a valid random_time_string, don't need parse
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score', 'raw_index'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca', 'id', 'cafe', 'filename'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced', 'expression', 'counts'
#     obsp: 'distances', 'connectivities'

# %%
cafe.plot.plot_graph(fadata, model_name=model_name)
# Out:
# DEBUG    |- calculate new milestone embedding for model_name:stavia_problem.
# DEBUG    |- 'stavia_problem' is not a valid random_time_string, don't need parse
# array([[<Axes: title={'center': 'stavia_problem(clusters)'}, xlabel='_milestone_network_emb1', ylabel='_milestone_network_emb2'>]],
#       dtype=object)

# %%
cafe.plot.plot_wrapper(fadata, model_name=model_name, wrapper_type="cluster")
# Out:
# DEBUG    |- No mode specified, using default for 'cluster': 'embedding'
# DEBUG    |- Dispatching to plotter 'cluster' with mode 'embedding'.
# DEBUG    |- extract 'clusters' from prior infomation as parameter 'color'
# DEBUG    |- extract 'X_umap' from prior infomation as parameter 'basis'
# DEBUG    |- calculate new trajectory embedding for model_name:ref, basis:X_umap.
# DEBUG    |- add waypoints
# DEBUG    |- FateAnnData add_waypoints
# DEBUG    |- add waypoints shape is (212, 3696) for 'ref', finished!
# DEBUG    |- plot_trajectory for model_name:'ref', color:'clusters'
# DEBUG    |- 'ref' is not a valid random_time_string, don't need parse
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cafe.plot.plot_wrapper(fadata, model_name=model_name, wrapper_type="cluster")
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/cafe/plot/plot_wrapper.py:48, in plot_wrapper(fadata, wrapper_type, model_name, mode, save, **kwargs)
#      46 # --- 4. Dispatch to the specific plot function ---
#      47 logger.debug(f"Dispatching to plotter '{wrapper_type}' with mode '{mode}'.")
# ---> 48 plot_function(fadata=fadata, model_name=model_name, **kwargs)
#      50 # --- 5. Save the figure if requested ---
#      51 if save is not None:
#
# File ~/miniconda3/envs/cafe/lib/python3.10/site-packages/cafe/plot/_wrapper_plots/cluster.py:18, in plot_embedding(fadata, model_name, basis)
#      14 ax = axes.flatten()[0]
#      16 # connect cell and milestone by cluster
#      17 # create edge dataframe
# ---> 18 edge_df = cluster.reset_index()
#      19 edge_df.columns = ["source", "target"]
#      20 G = nx.from_pandas_edgelist(edge_df, create_using=nx.Graph)
#
# AttributeError: 'list' object has no attribute 'reset_index'
