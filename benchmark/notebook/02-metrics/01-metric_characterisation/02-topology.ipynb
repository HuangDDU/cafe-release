# %%
import cfe
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 绘图相关
fontsize = 30
figure_dict = {}
# Out:
# [2025年03月20日 12时12分16秒] INFO
#                                           _____     _ _ ______    _       ______            _
#                                          / ____|   | | |  ____|  | |     |  ____|          | |
#                                         | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                         | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                         | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                          \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                                      | |
#                                                                                      |_|
# (eog:2531346): Gtk-WARNING **: 12:18:03.994: cannot open display:
#
# (eog:2531437): Gtk-WARNING **: 12:18:10.700: cannot open display:

# %% [markdown]
# ## 1. 构造数据并绘制拓扑图

# %%
# 导入数据
milestone_netowrk_dict = cfe.data.topologies_with_same_n_milestones

# 封装轨迹
fadata_dict = {}
for id, milestone_netowrk in milestone_netowrk_dict.items():
    fadata = cfe.data.generate_trajectory(milestone_netowrk, id)
    fadata_dict[id] = fadata


# 可视化
n = len(fadata_dict)
fig, ax = plt.subplots(1, n, figsize=(n * 5, 6), dpi=120)
i = 0
for id, trajectory in fadata_dict.items():
    cfe.plot.plot_topology(trajectory, ax=ax[i], nx_draw_kwrags={"node_size":1000 ,"font_size": fontsize, "width":3, "arrowsize":30})
    ax[i].set_title(id, fontdict={"size":fontsize})
    i += 1

figure_dict["topology"] = fig

# %%
# 合并到同一个 FateAnnData上
main_model_name = "linear"
fadata_merge = fadata_dict[main_model_name]

for model_name, fadata in fadata_dict.items():
    fadata_merge.trajectory_history_dict[model_name] = fadata.trajectory_history_dict["default"]


del fadata_merge.trajectory_history_dict["default"]
fadata_merge.model_name = main_model_name

model_name_list = fadata_merge.get_all_model_name()
model_name_list
# Out:
# [2025年03月20日 12时12分17秒] WARNING  'linear' is not a valid random_time_string, don't need parse
#                         WARNING  'bifurcation' is not a valid random_time_string, don't need parse
#                         WARNING  'multifurcating' is not a valid random_time_string, don't need parse
#                         WARNING  'tree' is not a valid random_time_string, don't need parse
#                         WARNING  'cycle' is not a valid random_time_string, don't need parse
#                         WARNING  'connected' is not a valid random_time_string, don't need parse
#                         WARNING  'disconnected' is not a valid random_time_string, don't need parse
# ['linear',
#  'bifurcation',
#  'multifurcating',
#  'tree',
#  'cycle',
#  'connected',
#  'disconnected']

# %% [markdown]
# ## 2. 模型交叉，指标计算并可视化

# %%
metrics = cfe.metric.metrics
metric_id_list = metrics[metrics["category"] == "topology"]["metric_id"].tolist()

metrics_result_dict = {}
for model_name1 in model_name_list:
    for model_name2 in model_name_list:
        model_metric = cfe.metric.calculate_metrics(
            fadata_merge,
            metrics=metric_id_list,
            now_model=model_name1,
            ref_model=model_name2,
            simplify=False # 对于环形轨迹目前的simplify不支持
        )
        metrics_result_dict[(model_name1, model_name2)] = model_metric

metrics_result_dict
# Out:
# {('linear', 'linear'): {'isomorphic': 1, 'edge_flip': 1.0, 'him': 0},
#  ('linear', 'bifurcation'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('linear', 'multifurcating'): {'isomorphic': 0, 'edge_flip': 0.5, 'him': 0},
#  ('linear', 'tree'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('linear', 'cycle'): {'isomorphic': 0,
#   'edge_flip': 0.8888888888888888,
#   'him': 0},
#  ('linear', 'connected'): {'isomorphic': 0,
#   'edge_flip': 0.8888888888888888,
#   'him': 0},
#  ('linear', 'disconnected'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('bifurcation', 'linear'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('bifurcation', 'bifurcation'): {'isomorphic': 1, 'edge_flip': 1.0, 'him': 0},
#  ('bifurcation', 'multifurcating'): {'isomorphic': 0,
#   'edge_flip': 0.75,
#   'him': 0},
#  ('bifurcation', 'tree'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('bifurcation', 'cycle'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('bifurcation', 'connected'): {'isomorphic': 0,
#   'edge_flip': 0.8888888888888888,
#   'him': 0},
#  ('bifurcation', 'disconnected'): {'isomorphic': 0,
#   'edge_flip': 0.5,
#   'him': 0},
#  ('multifurcating', 'linear'): {'isomorphic': 0, 'edge_flip': 0.5, 'him': 0},
#  ('multifurcating', 'bifurcation'): {'isomorphic': 0,
#   'edge_flip': 0.75,
#   'him': 0},
#  ('multifurcating', 'multifurcating'): {'isomorphic': 1,
#   'edge_flip': 1.0,
#   'him': 0},
#  ('multifurcating', 'tree'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('multifurcating', 'cycle'): {'isomorphic': 0,
#   'edge_flip': 0.4444444444444444,
#   'him': 0},
#  ('multifurcating', 'connected'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('multifurcating', 'disconnected'): {'isomorphic': 0,
#   'edge_flip': 0.5,
#   'him': 0},
#  ('tree', 'linear'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('tree', 'bifurcation'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('tree', 'multifurcating'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('tree', 'tree'): {'isomorphic': 1, 'edge_flip': 1.0, 'him': 0},
#  ('tree', 'cycle'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('tree', 'connected'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('tree', 'disconnected'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('cycle', 'linear'): {'isomorphic': 0,
#   'edge_flip': 0.8888888888888888,
#   'him': 0},
#  ('cycle', 'bifurcation'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('cycle', 'multifurcating'): {'isomorphic': 0,
#   'edge_flip': 0.4444444444444444,
#   'him': 0},
#  ('cycle', 'tree'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('cycle', 'cycle'): {'isomorphic': 1, 'edge_flip': 1.0, 'him': 0},
#  ('cycle', 'connected'): {'isomorphic': 0, 'edge_flip': 0.8, 'him': 0},
#  ('cycle', 'disconnected'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('connected', 'linear'): {'isomorphic': 0,
#   'edge_flip': 0.8888888888888888,
#   'him': 0},
#  ('connected', 'bifurcation'): {'isomorphic': 0,
#   'edge_flip': 0.8888888888888888,
#   'him': 0},
#  ('connected', 'multifurcating'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('connected', 'tree'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('connected', 'cycle'): {'isomorphic': 0, 'edge_flip': 0.8, 'him': 0},
#  ('connected', 'connected'): {'isomorphic': 1, 'edge_flip': 1.0, 'him': 0},
#  ('connected', 'disconnected'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('disconnected', 'linear'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('disconnected', 'bifurcation'): {'isomorphic': 0,
#   'edge_flip': 0.5,
#   'him': 0},
#  ('disconnected', 'multifurcating'): {'isomorphic': 0,
#   'edge_flip': 0.5,
#   'him': 0},
#  ('disconnected', 'tree'): {'isomorphic': 0, 'edge_flip': 0.75, 'him': 0},
#  ('disconnected', 'cycle'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('disconnected', 'connected'): {'isomorphic': 0,
#   'edge_flip': 0.6666666666666667,
#   'him': 0},
#  ('disconnected', 'disconnected'): {'isomorphic': 1,
#   'edge_flip': 1.0,
#   'him': 0}}

# %% [markdown]
# 可视化

# %%
# 构建空dataframe
metric_dataframe_dict = {}
for metric_id in metric_id_list:
    metric_dataframe_dict[metric_id] = pd.DataFrame(columns=model_name_list, index=model_name_list, dtype="float")


# 填充dataframe
for trajectory_id_tuple in metrics_result_dict.keys():
    trajectory_id1, trajectory_id2 = trajectory_id_tuple
    for metric_id in metric_id_list:
        metric_dataframe_dict[metric_id].loc[trajectory_id1, trajectory_id2] = metrics_result_dict[trajectory_id_tuple][metric_id]

# 可视化dataframe
n = len(metric_id_list)
fig, ax = plt.subplots(1, n, figsize=(n * 12, 12), dpi=120)
i = 0
for metric_id in metric_id_list:
    sns.heatmap(metric_dataframe_dict[metric_id], annot_kws={"fontsize":fontsize}, ax=ax[i], annot=True, cmap="YlGnBu", cbar=False)
    # ax[i].tick_params(axis="both", labelsize=fontsize) 
    ax[i].set_yticklabels(ax[i].get_yticklabels(), rotation=0, fontsize=fontsize)
    ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45, fontsize=fontsize)

    if not i == 0:
        ax[i].set_yticks([])
    ax[i].set_title(metric_id, fontdict={"size":fontsize})
    i += 1

figure_dict["topology_metric_heatmap"] = fig

# %% [markdown]
# ## 3. 细微干扰测试，调整边长

# %%
# 细微干扰数据基于milestone_network
topology = pd.DataFrame(
    data=[
        ["A", "B"],
        ["B", "D"],
        ["B", "C"],
        ["D", "E"],
        ["D", "F"],
    ],
    columns=["from", "to"]
)
# 在DE，DE边上延长
new_length_list = [0, 0.05, 0.5, 1]
milestone_netowrk_dict = {}
for new_length in new_length_list:
    milestone_netowrk = topology.copy()
    milestone_netowrk["directed "] = True
    milestone_netowrk["length"] = 1
    milestone_netowrk.loc[milestone_netowrk.apply(lambda x: x["from"]=="D", axis=1), "length"] = new_length
    milestone_netowrk = milestone_netowrk[milestone_netowrk["length"] !=0] # 过滤为0的边
    milestone_netowrk_dict[new_length] = milestone_netowrk

milestone_netowrk_dict
# Out:
# {0:   from to  directed   length
#  0    A  B       True       1
#  1    B  D       True       1
#  2    B  C       True       1,
#  0.05:   from to  directed   length
#  0    A  B       True    1.00
#  1    B  D       True    1.00
#  2    B  C       True    1.00
#  3    D  E       True    0.05
#  4    D  F       True    0.05,
#  0.5:   from to  directed   length
#  0    A  B       True     1.0
#  1    B  D       True     1.0
#  2    B  C       True     1.0
#  3    D  E       True     0.5
#  4    D  F       True     0.5,
#  1:   from to  directed   length
#  0    A  B       True       1
#  1    B  D       True       1
#  2    B  C       True       1
#  3    D  E       True       1
#  4    D  F       True       1}

# %%
# 构造轨迹
fadata_dict = {}
for id, milestone_netowrk in milestone_netowrk_dict.items():
    trajectory = cfe.data.generate_trajectory(milestone_netowrk, id)
    fadata_dict[id] = trajectory

# 可视化
n = len(fadata_dict)
fig, ax = plt.subplots(1, n, figsize=(n * 5, 5), dpi=120)
i = 0
for id, trajectory in fadata_dict.items():
    cfe.plot.plot_topology(trajectory, ax=ax[i], nx_draw_kwrags={"node_size":1000 ,"font_size": fontsize, "width":3, "arrowsize":30}, layout="neato")
    ax[i].set_title(id, fontdict={"size":fontsize})
    i += 1

figure_dict["perturbation_topology"] = fig

# %%
# 合并到同一个 FateAnnData上
main_model_name = 0
fadata_merge = fadata_dict[main_model_name]

for model_name, fadata in fadata_dict.items():
    model_name = str(model_name) # 转化为数字
    fadata_merge.trajectory_history_dict[model_name] = fadata.trajectory_history_dict["default"]


del fadata_merge.trajectory_history_dict["default"]
fadata_merge.model_name = str(main_model_name)

model_name_list = fadata_merge.get_all_model_name()
model_name_list
# Out:
# [2025年03月20日 12时12分18秒] WARNING  '0' is not a valid random_time_string, don't need parse
#                         WARNING  '0.05' is not a valid random_time_string, don't need parse
#                         WARNING  '0.5' is not a valid random_time_string, don't need parse
#                         WARNING  '1' is not a valid random_time_string, don't need parse
# ['0', '0.05', '0.5', '1']

# %%
metrics_result_dict = {}
for model_name in model_name_list:
    model_metric = cfe.metric.calculate_metrics(
        fadata_merge,
        metrics=metric_id_list,
        now_model=model_name,
        ref_model="0"
    )
    metrics_result_dict[model_name] = model_metric

metric_result_df = pd.DataFrame(metrics_result_dict)
metric_result_df.style.background_gradient(cmap="Blues").format("{:.2g}")
# Out:
# <style type="text/css">
# #T_708d3_row0_col0, #T_708d3_row1_col0, #T_708d3_row1_col1, #T_708d3_row1_col2, #T_708d3_row1_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_708d3_row0_col1, #T_708d3_row0_col2, #T_708d3_row0_col3, #T_708d3_row2_col0, #T_708d3_row2_col1, #T_708d3_row2_col2, #T_708d3_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_708d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_708d3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_708d3_level0_col1" class="col_heading level0 col1" >0.05</th>
#       <th id="T_708d3_level0_col2" class="col_heading level0 col2" >0.5</th>
#       <th id="T_708d3_level0_col3" class="col_heading level0 col3" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_708d3_level0_row0" class="row_heading level0 row0" >isomorphic</th>
#       <td id="T_708d3_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_708d3_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_708d3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_708d3_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_708d3_level0_row1" class="row_heading level0 row1" >edge_flip</th>
#       <td id="T_708d3_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_708d3_row1_col1" class="data row1 col1" >0.67</td>
#       <td id="T_708d3_row1_col2" class="data row1 col2" >0.67</td>
#       <td id="T_708d3_row1_col3" class="data row1 col3" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_708d3_level0_row2" class="row_heading level0 row2" >him</th>
#       <td id="T_708d3_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_708d3_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_708d3_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_708d3_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 修改图片尺寸，图片字体会拉伸
# TODO: 整成PDF矢量图

base_name = "../../../result/02-metrics/01-metric_characterisation/02-topology"

figure_name_list = list(figure_dict.keys())
figure_list = list(figure_dict.values())
fig, axes = plt.subplots(len(figure_name_list), 1, figsize=(10, 4 * len(figures)))

for i in range(len(figure_name_list)):
    figure_name = figure_name_list[i]
    figure = figure_list[i]
    ax = axes[i]
    figure.savefig(f"{base_name}/{figure_name}.pdf")
    ax.imshow(figure.canvas.renderer.buffer_rgba())
    ax.axis("off")

plt.tight_layout()
plt.savefig(f"{base_name}.pdf")
plt.show()

# %%
# # 不修改原图片尺寸
# # 获取所有子图的原始尺寸（单位：英寸）
# fig_sizes = [old_fig.get_size_inches() for old_fig in figures]
# widths, heights = zip(*fig_sizes)
# total_height = sum(heights)  # 总高度 = 所有子图高度之和
# max_width = max(widths)      # 最大宽度 = 所有子图的最大宽度

# fig = plt.figure(figsize=(max_width, total_height))

# from matplotlib import gridspec

# # 创建垂直排列的网格布局
# gs = gridspec.GridSpec(len(figures), 1, height_ratios=heights)  # 按原始高度比例分配空间
# axes = [fig.add_subplot(gs[i]) for i in range(len(figures))]

# # 显示图像并隐藏坐标轴
# for ax, old_fig in zip(axes, figures):
#     ax.imshow(old_fig.canvas.renderer.buffer_rgba())
#     ax.axis('off')

# plt.tight_layout(pad=0)  # pad=0 表示完全去除子图间的边距
# plt.savefig("../../../result/02-metrics/01-metric_characterisation/02-topology2.pdf")
# plt.show()

# %%
# # patchworklib拼图, 只能事前拼图
# # 使用示例
# import patchworklib as pw

# # 创建子图
# fig1 = pw.Brick(figsize=(6, 2))  # 类似 wrap_elements()
# fig2 = pw.Brick(figsize=(6, 5))
# fig3 = pw.Brick(figsize=(6, 5))


# # 拼接
# combined = (fig1 / fig2 / fig3)
# combined.set_suptitle("(a) Combined Plots", loc="left")

# # 保存或显示
# combined.savefig("combined.pdf", bbox_inches="tight")
# plt.show()
